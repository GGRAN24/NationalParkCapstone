# %%
 
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
nps_deaths=pd.read_csv('../data/nps_fatality_stats.csv')

# %%
nps_deaths.head()
# Out:
#   Incident Date                             Park Name       Cause of Death  \
# 0      1/1/2007  Glen Canyon National Recreation Area         Undetermined
# 1     1/22/2007  Golden Gate National Recreation Area             Drowning
# 2     1/22/2007  Golden Gate National Recreation Area         Undetermined
# 3     1/29/2007                 Natchez Trace Parkway  Motor Vehicle Crash
# 4     1/29/2007                 Natchez Trace Parkway  Motor Vehicle Crash
#
#   Cause of Death Group \n(Used in the NPS Mortality Dashboard)   \
# 0                                       Undetermined
# 1                                           Drowning
# 2                                       Undetermined
# 3                                Motor Vehicle Crash
# 4                                Motor Vehicle Crash
#
#           Intent       Outcome     Sex     Age Range        Activity
# 0   Undetermined  Fatal injury    Male           65+    Not Reported
# 1  Unintentional  Fatal injury    Male  Not Reported  Vessel Related
# 2   Undetermined  Fatal injury    Male  Not Reported  Vessel Related
# 3  Unintentional  Fatal injury  Female         15-24        Driving
# 4  Unintentional  Fatal injury  Female         45-54        Driving

# %%
nps_deaths.shape
# Out:
# (4635, 9)

# %%
Guad_nps_df=pd.read_csv('../data/Guadalupe_pop.csv',skiprows=3)
Guad_nps_df['park']='Guadalupe Mountains National Park'
Guad_nps_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors  \
# 0  1971             27,100               8,639,984
#
#                                 park
# 0  Guadalupe Mountains National Park

# %%
Grand_Teton_pop_df=pd.read_csv('../data/Grand_Teton_pop.csv',skiprows=3)
Grand_Teton_pop_df['park']='Grand Teton National Park'
Grand_Teton_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                       park
# 0  1929             51,500             171,510,364  Grand Teton National Park

# %%
Grand_Canyon_pop_df=pd.read_csv('../data/Grand_Canyon_pop.csv',skiprows=3)
Grand_Canyon_pop_df['park']='Grand Canyon National Park'
Grand_Canyon_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                        park
# 0  1919             37,745             240,991,619  Grand Canyon National Park

# %%
Glacier_pop_df=pd.read_csv('../data/Glacier_pop.csv',skiprows=3)
Glacier_pop_df['park']='Glacier National Park'
Glacier_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                   park
# 0  1911              4,000             124,972,813  Glacier National Park

# %%
Carlsbad_Caverns_pop_df=pd.read_csv('../data/Carlsbad_Caverns.csv',skiprows=3)
Carlsbad_Caverns_pop_df['park']='Carlsbad Caverns National Park'
Carlsbad_Caverns_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors  \
# 0  1924              1,280              46,478,465
#
#                              park
# 0  Carlsbad Caverns National Park

# %%
Canyonlands_pop_df=pd.read_csv('../data/Canyonlands_pop.csv',skiprows=3)
Canyonlands_pop_df['park']='Canyonlands National Park'
Canyonlands_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                       park
# 0  1965             19,400              19,190,788  Canyonlands National Park

# %%
Bryce_Canyon_pop_df=pd.read_csv('../data/Bryce_Canyon_pop.csv',skiprows=3)
Bryce_Canyon_pop_df['park']='Bryce Canyon National Park'
Bryce_Canyon_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                        park
# 0  1929             21,997              65,941,639  Bryce Canyon National Park

# %%
Black_Canyon_pop_df=pd.read_csv('../data/Black_Canyon_pop.csv',skiprows=3)
Black_Canyon_pop_df['park']='Black Canyon Of The Gunnison National Park'
Black_Canyon_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors  \
# 0  1934              2,592              16,040,142
#
#                                          park
# 0  Black Canyon Of The Gunnison National Park

# %%
Big_Bend_pop_df=pd.read_csv('../data/Big_Bend_pop.csv',skiprows=3)
Big_Bend_pop_df['park']='Big Bend National Park'
Big_Bend_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                    park
# 0  1944              1,409              19,162,799  Big Bend National Park

# %%
Arches_pop_df=pd.read_csv('../data/Arches_pop.csv',skiprows=3)
Arches_pop_df['park']='Arches National Park'
Arches_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                  park
# 0  1929                500              43,427,888  Arches National Park

# %%
Great_Sand_Dunes_pop_df=pd.read_csv('../data/Great_Sand_Dunes_pop.csv',skiprows=3)
Great_Sand_Dunes_pop_df['park']='Great Sand Dunes National Park & Preserve'
Great_Sand_Dunes_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors  \
# 0  1932                500              17,054,087
#
#                                         park
# 0  Great Sand Dunes National Park & Preserve

# %%
Great_Sand_Dunes_pop_df.to_csv('Great_Sand_Dunes_pop_df.csv', index=False)

# %%
Zion_pop_df=pd.read_csv('../data/Zion_pop.csv',skiprows=3)
Zion_pop_df['park']='Zion National Park'
Zion_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                park
# 0  1919              1,814             142,570,935  Zion National Park

# %%
Yellowstone_pop_df=pd.read_csv('../data/Yellowstone_pop.csv',skiprows=3)
Yellowstone_pop_df['park']='Yellowstone National Park'
Yellowstone_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                       park
# 0  1904             13,727             203,750,110  Yellowstone National Park

# %%
White_Sands_pop_df=pd.read_csv('../data/White_Sands_pop.csv',skiprows=3)
White_Sands_pop_df['park']='White Sands National Park'
White_Sands_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                       park
# 0  1933             12,000              38,276,355  White Sands National Park

# %%
Saguaro_pop_df=pd.read_csv('../data/Saguaro_pop.csv',skiprows=3)
Saguaro_pop_df['park']='Saguaro National Park'
Saguaro_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                   park
# 0  1920              5,000              39,873,266  Saguaro National Park

# %%
Rocky_Mountain_pop_df=pd.read_csv('../data/Rocky_Mountain_pop.csv',skiprows=3)
Rocky_Mountain_pop_df['park']='Rocky Mountain National Park'
Rocky_Mountain_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors  \
# 0  1915             31,000             209,930,678
#
#                            park
# 0  Rocky Mountain National Park

# %%
Petrified_Forest_pop_df=pd.read_csv('../data/Petrified_Forest_pop.csv',skiprows=3)
Petrified_Forest_pop_df['park']='Petrified Forest National Park'
Petrified_Forest_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors  \
# 0  1919              3,000              58,055,578
#
#                              park
# 0  Petrified Forest National Park

# %%
Mesa_Verde_pop_df=pd.read_csv('../data/Mesa_Verde_pop.csv',skiprows=3)
Mesa_Verde_pop_df['park']='Mesa Verde National Park'
Mesa_Verde_pop_df.head(1)
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                      park
# 0  1908                 80              36,438,206  Mesa Verde National Park

# %% [markdown]
# Combining population data

# %%
concat_data = pd.concat([Mesa_Verde_pop_df,Petrified_Forest_pop_df,Rocky_Mountain_pop_df,Saguaro_pop_df,White_Sands_pop_df,Yellowstone_pop_df,Zion_pop_df,Great_Sand_Dunes_pop_df,Arches_pop_df,Big_Bend_pop_df])
concat_data
# Out:
#     Year RecreationVisitors TotalRecreationVisitors                      park
# 0   1908                 80              36,438,206  Mesa Verde National Park
# 1   1909                165              36,438,206  Mesa Verde National Park
# 2   1910                250              36,438,206  Mesa Verde National Park
# 3   1911                206              36,438,206  Mesa Verde National Park
# 4   1912                230              36,438,206  Mesa Verde National Park
# ..   ...                ...                     ...                       ...
# 75  2019            463,832              19,162,799    Big Bend National Park
# 76  2020            393,907              19,162,799    Big Bend National Park
# 77  2021            581,220              19,162,799    Big Bend National Park
# 78  2022            514,107              19,162,799    Big Bend National Park
# 79  2023            509,129              19,162,799    Big Bend National Park
#
# [1013 rows x 4 columns]

# %%
concat_2=pd.concat([concat_data,Black_Canyon_pop_df,Bryce_Canyon_pop_df,Canyonlands_pop_df,Carlsbad_Caverns_pop_df,Glacier_pop_df,Grand_Canyon_pop_df,Grand_Teton_pop_df,Guad_nps_df])
concat_2.head()
# Out:
#    Year RecreationVisitors TotalRecreationVisitors                      park
# 0  1908                 80              36,438,206  Mesa Verde National Park
# 1  1909                165              36,438,206  Mesa Verde National Park
# 2  1910                250              36,438,206  Mesa Verde National Park
# 3  1911                206              36,438,206  Mesa Verde National Park
# 4  1912                230              36,438,206  Mesa Verde National Park

# %%
Intermountain_parkpop_df=concat_2.drop(columns=['TotalRecreationVisitors'])
Intermountain_parkpop_df
# Out:
#     Year RecreationVisitors                               park
# 0   1908                 80           Mesa Verde National Park
# 1   1909                165           Mesa Verde National Park
# 2   1910                250           Mesa Verde National Park
# 3   1911                206           Mesa Verde National Park
# 4   1912                230           Mesa Verde National Park
# ..   ...                ...                                ...
# 48  2019            188,833  Guadalupe Mountains National Park
# 49  2020            151,256  Guadalupe Mountains National Park
# 50  2021            243,291  Guadalupe Mountains National Park
# 51  2022            219,987  Guadalupe Mountains National Park
# 52  2023            227,340  Guadalupe Mountains National Park
#
# [1723 rows x 3 columns]

# %%
Intermountain_parkpop_df=Intermountain_parkpop_df.rename(columns={'RecreationVisitors':'Visitors'})

# %%
Intermountain_parkpop_df['Year']=Intermountain_parkpop_df['Year'].astype(str)

# %%
Intermountain_parkpop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1723 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      1723 non-null   object
#  1   Visitors  1723 non-null   object
#  2   park      1723 non-null   object
# dtypes: object(3)
# memory usage: 53.8+ KB

# %%
Intermountain_parkpop_df
# Out:
#     Year Visitors                               park
# 0   1908       80           Mesa Verde National Park
# 1   1909      165           Mesa Verde National Park
# 2   1910      250           Mesa Verde National Park
# 3   1911      206           Mesa Verde National Park
# 4   1912      230           Mesa Verde National Park
# ..   ...      ...                                ...
# 48  2019  188,833  Guadalupe Mountains National Park
# 49  2020  151,256  Guadalupe Mountains National Park
# 50  2021  243,291  Guadalupe Mountains National Park
# 51  2022  219,987  Guadalupe Mountains National Park
# 52  2023  227,340  Guadalupe Mountains National Park
#
# [1723 rows x 3 columns]

# %%
Intermountain_parkpop = Intermountain_parkpop_df[(Intermountain_parkpop_df['Year'] >= '2007') & 
                     (Intermountain_parkpop_df['Year'] < '2024')]
Intermountain_parkpop.head(20)
# Out:
#      Year Visitors                            park
# 99   2007  541,102        Mesa Verde National Park
# 100  2008  551,446        Mesa Verde National Park
# 101  2009  550,377        Mesa Verde National Park
# 102  2010  559,712        Mesa Verde National Park
# 103  2011  572,329        Mesa Verde National Park
# 104  2012  488,860        Mesa Verde National Park
# 105  2013  460,237        Mesa Verde National Park
# 106  2014  501,563        Mesa Verde National Park
# 107  2015  547,325        Mesa Verde National Park
# 108  2016  583,527        Mesa Verde National Park
# 109  2017  613,788        Mesa Verde National Park
# 110  2018  563,420        Mesa Verde National Park
# 111  2019  556,203        Mesa Verde National Park
# 112  2020  287,477        Mesa Verde National Park
# 113  2021  548,477        Mesa Verde National Park
# 114  2022  499,790        Mesa Verde National Park
# 115  2023  505,194        Mesa Verde National Park
# 88   2007  563,590  Petrified Forest National Park
# 89   2008  543,714  Petrified Forest National Park
# 90   2009  631,613  Petrified Forest National Park

# %%
Intermountain_parkpop.columns
# Out:
# Index(['Year', 'Visitors', 'park'], dtype='object')

# %% [markdown]
# WHAT IS THE TOTAL VISITORS PER YEAR THROUGH ALL INTERMOUNTAINOUS NATIONAL PARKS

# %%
Intermountain_parkpop.groupby(['Year','park'])
Intermountain_parkpop.head()
# Out:
#      Year Visitors                      park
# 99   2007  541,102  Mesa Verde National Park
# 100  2008  551,446  Mesa Verde National Park
# 101  2009  550,377  Mesa Verde National Park
# 102  2010  559,712  Mesa Verde National Park
# 103  2011  572,329  Mesa Verde National Park

# %%
Intermountain_parkpop['Year']=Intermountain_parkpop['Year'].astype(int)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\606800316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intermountain_parkpop['Year']=Intermountain_parkpop['Year'].astype(int)

# %%
Intermountain_parkpop['Visitors']=Intermountain_parkpop['Visitors'].str.replace(',' , '')
Intermountain_parkpop
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\744248895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intermountain_parkpop['Visitors']=Intermountain_parkpop['Visitors'].str.replace(',' , '')
#      Year Visitors                               park
# 99   2007   541102           Mesa Verde National Park
# 100  2008   551446           Mesa Verde National Park
# 101  2009   550377           Mesa Verde National Park
# 102  2010   559712           Mesa Verde National Park
# 103  2011   572329           Mesa Verde National Park
# ..    ...      ...                                ...
# 48   2019   188833  Guadalupe Mountains National Park
# 49   2020   151256  Guadalupe Mountains National Park
# 50   2021   243291  Guadalupe Mountains National Park
# 51   2022   219987  Guadalupe Mountains National Park
# 52   2023   227340  Guadalupe Mountains National Park
#
# [306 rows x 3 columns]

# %%
Intermountain_parkpop['Visitors']=Intermountain_parkpop['Visitors'].astype(int)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\749589372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intermountain_parkpop['Visitors']=Intermountain_parkpop['Visitors'].astype(int)

# %% [markdown]
# WHAT IS THE TOTAL NUMBER OF VISITORS OF THE INTERMOUNTAINOUS REGION

# %%
Intermountain_parkpop.to_csv('Intermountain_parkpop.csv',index=False)

# %%
Intermountain_parkpop['Visitors'].sum()
# Out:
# 496427574

# %%
Intermountain_parkpop.head(1)
# Out:
#     Year  Visitors                      park
# 99  2007    541102  Mesa Verde National Park

# %% [markdown]
# Visitor trend from 2007 to 2023

# %%
Intermountain_parkpop_2007=Intermountain_parkpop.loc[Intermountain_parkpop['Year']==2007]
Intermountain_parkpop_2007
# Out:
#      Year  Visitors                                        park
# 99   2007    541102                    Mesa Verde National Park
# 88   2007    563590              Petrified Forest National Park
# 92   2007   2895383                Rocky Mountain National Park
# 84   2007    658477                       Saguaro National Park
# 74   2007    437042                   White Sands National Park
# 103  2007   3151343                   Yellowstone National Park
# 88   2007   2657281                          Zion National Park
# 74   2007    285121   Great Sand Dunes National Park & Preserve
# 78   2007    860181                        Arches National Park
# 63   2007    364856                      Big Bend National Park
# 73   2007    219576  Black Canyon Of The Gunnison National Park
# 78   2007   1012563                  Bryce Canyon National Park
# 42   2007    417560                   Canyonlands National Park
# 83   2007    409560              Carlsbad Caverns National Park
# 96   2007   2083329                       Glacier National Park
# 88   2007   4413668                  Grand Canyon National Park
# 78   2007   2588574                   Grand Teton National Park
# 36   2007    165110           Guadalupe Mountains National Park

# %%
Intermountain_parkpop_2023=Intermountain_parkpop.loc[Intermountain_parkpop['Year']==2023]
Intermountain_parkpop_2023
# Out:
#      Year  Visitors                                        park
# 115  2023    505194                    Mesa Verde National Park
# 104  2023    520491              Petrified Forest National Park
# 108  2023   4115837                Rocky Mountain National Park
# 100  2023   1010906                       Saguaro National Park
# 90   2023    729096                   White Sands National Park
# 119  2023   4501382                   Yellowstone National Park
# 104  2023   4623238                          Zion National Park
# 90   2023    512219   Great Sand Dunes National Park & Preserve
# 94   2023   1482045                        Arches National Park
# 79   2023    509129                      Big Bend National Park
# 89   2023    357069  Black Canyon Of The Gunnison National Park
# 94   2023   2461269                  Bryce Canyon National Park
# 58   2023    800322                   Canyonlands National Park
# 99   2023    394121              Carlsbad Caverns National Park
# 112  2023   2933616                       Glacier National Park
# 104  2023   4733705                  Grand Canyon National Park
# 94   2023   3417106                   Grand Teton National Park
# 52   2023    227340           Guadalupe Mountains National Park

# %%
Intermountain_parkpop.loc[Intermountain_parkpop['Year']==2007]['Visitors'].sum()
# Out:
# 23724316

# %%
Intermountain_parkpop.loc[Intermountain_parkpop['Year']==2023]['Visitors'].sum()
# Out:
# 33834085

# %% [markdown]
# TOTAL VISITORS OF ALL PARKS PER YEAR

# %%
plt.figure(figsize=(10,8))
sns.relplot(x='Year', y='Visitors', data=Intermountain_parkpop.groupby('Year')['Visitors'].sum().reset_index(), color='darkgreen', label='Value',kind='line')
plt.ylim(0)
plt.title('  Total IMR National Park Visitors Per Year', fontsize=15)
plt.xlabel(' ')
plt.ylabel('Visitors', fontsize=14)
#plt.savefig('total_line_plot3.png',bbox_inches = 'tight', transparent=True);
# Out:
# Text(9.444444444444445, 0.5, 'Visitors')

# %%
Intermountain_parkpop['Visitors']=(Intermountain_parkpop['Visitors']/1000).round()
Intermountain_parkpop
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\971345702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Intermountain_parkpop['Visitors']=(Intermountain_parkpop['Visitors']/1000).round()
#      Year  Visitors                               park
# 99   2007     541.0           Mesa Verde National Park
# 100  2008     551.0           Mesa Verde National Park
# 101  2009     550.0           Mesa Verde National Park
# 102  2010     560.0           Mesa Verde National Park
# 103  2011     572.0           Mesa Verde National Park
# ..    ...       ...                                ...
# 48   2019     189.0  Guadalupe Mountains National Park
# 49   2020     151.0  Guadalupe Mountains National Park
# 50   2021     243.0  Guadalupe Mountains National Park
# 51   2022     220.0  Guadalupe Mountains National Park
# 52   2023     227.0  Guadalupe Mountains National Park
#
# [306 rows x 3 columns]

# %%
Intermountain_parkpop=Intermountain_parkpop.rename(columns={'Visitors':'Visitors(1000s)'})
Intermountain_parkpop.head(1)
# Out:
#     Year  Visitors(1000s)                      park
# 99  2007            541.0  Mesa Verde National Park

# %%
Intermountain_parkpop.groupby('Year')['Visitors(1000s)'].sum().reset_index()
# Out:
#     Year  Visitors(1000s)
# 0   2007          23725.0
# 1   2008          23236.0
# 2   2009          24234.0
# 3   2010          25120.0
# 4   2011          24500.0
# 5   2012          25364.0
# 6   2013          24832.0
# 7   2014          27138.0
# 8   2015          30818.0
# 9   2016          34250.0
# 10  2017          35587.0
# 11  2018          35541.0
# 12  2019          35481.0
# 13  2020          25166.0
# 14  2021          35744.0
# 15  2022          31856.0
# 16  2023          33832.0

# %%
Intermountain_parkpop.sort_values(by='Year',ascending=True).tail(30)
# Out:
#      Year  Visitors(1000s)                                        park
# 114  2022            500.0                    Mesa Verde National Park
# 89   2022            705.0                   White Sands National Park
# 103  2022           4732.0                  Grand Canyon National Park
# 93   2022           2355.0                  Bryce Canyon National Park
# 99   2022            908.0                       Saguaro National Park
# 89   2022            493.0   Great Sand Dunes National Park & Preserve
# 57   2022            779.0                   Canyonlands National Park
# 107  2022           4300.0                Rocky Mountain National Park
# 98   2022            391.0              Carlsbad Caverns National Park
# 103  2022            505.0              Petrified Forest National Park
# 88   2022            297.0  Black Canyon Of The Gunnison National Park
# 93   2022           2806.0                   Grand Teton National Park
# 94   2023           1482.0                        Arches National Park
# 104  2023           4734.0                  Grand Canyon National Park
# 115  2023            505.0                    Mesa Verde National Park
# 104  2023            520.0              Petrified Forest National Park
# 108  2023           4116.0                Rocky Mountain National Park
# 100  2023           1011.0                       Saguaro National Park
# 90   2023            729.0                   White Sands National Park
# 119  2023           4501.0                   Yellowstone National Park
# 94   2023           3417.0                   Grand Teton National Park
# 104  2023           4623.0                          Zion National Park
# 79   2023            509.0                      Big Bend National Park
# 89   2023            357.0  Black Canyon Of The Gunnison National Park
# 94   2023           2461.0                  Bryce Canyon National Park
# 58   2023            800.0                   Canyonlands National Park
# 99   2023            394.0              Carlsbad Caverns National Park
# 112  2023           2934.0                       Glacier National Park
# 90   2023            512.0   Great Sand Dunes National Park & Preserve
# 52   2023            227.0           Guadalupe Mountains National Park

# %%
plt.figure(figsize=(10,8))
sns.relplot(x='Year', y='Visitors(1000s)', data=Intermountain_parkpop.groupby('Year')['Visitors(1000s)'].sum().reset_index(), color='darkgreen', label='Value',kind='line')
plt.ylim(0)
plt.title('  Total IMR National Park Visitors Per Year', fontsize=15)
plt.xlabel(' ')
##plt.ylabel('Visitors(1000s)', fontsize=14)
plt.savefig('total_line_plot3.png',bbox_inches = 'tight', transparent=True);

# %%
plt.figure(figsize=(10,8))
sns.relplot(x='Year', y='Visitors(1000s)', data=Intermountain_parkpop.groupby('Year')['Visitors(1000s)'].sum().reset_index(), marker='o', linestyle='-', color='darkgreen', label='Value',kind='line')
plt.ylim(0)
plt.title('  Total IMR National Park Visitors Per Year', fontsize=15)
plt.xlabel(' ')
plt.ylabel('Visitors(1000s)', fontsize=14)
#plt.savefig('total_line_plot2.png',bbox_inches = 'tight', transparent=True);
# Out:
# Text(-12.805555555555555, 0.5, 'Visitors(1000s)')

# %%
Intermountain_parkpop.groupby('Year')['Visitors(1000s)'].sum().reset_index()
# Out:
#     Year  Visitors(1000s)
# 0   2007          23725.0
# 1   2008          23236.0
# 2   2009          24234.0
# 3   2010          25120.0
# 4   2011          24500.0
# 5   2012          25364.0
# 6   2013          24832.0
# 7   2014          27138.0
# 8   2015          30818.0
# 9   2016          34250.0
# 10  2017          35587.0
# 11  2018          35541.0
# 12  2019          35481.0
# 13  2020          25166.0
# 14  2021          35744.0
# 15  2022          31856.0
# 16  2023          33832.0

# %%
Intermountain_parkpop.groupby('Year')['Visitors(1000s)'].sum().describe()
# Out:
# count       17.000000
# mean     29201.411765
# std       5019.766517
# min      23236.000000
# 25%      24832.000000
# 50%      27138.000000
# 75%      34250.000000
# max      35744.000000
# Name: Visitors(1000s), dtype: float64

# %% [markdown]
# % change in total visitors since 2007:53%

# %%
 (35744.000000-23236.000000)/23236
# Out:
# 0.5383026338440351

# %%
visitors_sum=Intermountain_parkpop['Visitors(1000s)'].sum()
visitors_sum
# Out:
# 496424.0

# %%
Intermountain_parkpop
# Out:
#      Year  Visitors(1000s)                               park
# 99   2007            541.0           Mesa Verde National Park
# 100  2008            551.0           Mesa Verde National Park
# 101  2009            550.0           Mesa Verde National Park
# 102  2010            560.0           Mesa Verde National Park
# 103  2011            572.0           Mesa Verde National Park
# ..    ...              ...                                ...
# 48   2019            189.0  Guadalupe Mountains National Park
# 49   2020            151.0  Guadalupe Mountains National Park
# 50   2021            243.0  Guadalupe Mountains National Park
# 51   2022            220.0  Guadalupe Mountains National Park
# 52   2023            227.0  Guadalupe Mountains National Park
#
# [306 rows x 3 columns]

# %%
Parkpop_forgraph=Intermountain_parkpop.groupby('park')['Visitors(1000s)'].mean().reset_index()
Parkpop_forgraph
# Out:
#                                           park  Visitors(1000s)
# 0                         Arches National Park      1300.882353
# 1                       Big Bend National Park       403.588235
# 2   Black Canyon Of The Gunnison National Park       249.882353
# 3                   Bryce Canyon National Park      1784.058824
# 4                    Canyonlands National Park       604.058824
# 5               Carlsbad Caverns National Park       403.647059
# 6                        Glacier National Park      2466.117647
# 7                   Grand Canyon National Park      4859.470588
# 8                    Grand Teton National Park      3007.529412
# 9    Great Sand Dunes National Park & Preserve       376.352941
# 10           Guadalupe Mountains National Park       183.764706
# 11                    Mesa Verde National Park       525.235294
# 12              Petrified Forest National Park       618.705882
# 13                Rocky Mountain National Park      3693.529412
# 14                       Saguaro National Park       800.705882
# 15                   White Sands National Park       541.058824
# 16                   Yellowstone National Park      3750.588235
# 17                          Zion National Park      3632.235294

# %% [markdown]
# TOTAL VISITORS PER PARK

# %%
plt.figure(figsize = (10,6))

ax=sns.barplot(data =Parkpop_forgraph .sort_values('Visitors(1000s)',ascending=False),
               x = 'Visitors(1000s)',
               y = 'park', color='darkgreen',         
                errorbar=None)


plt.title('Average Total Visitors Per Park Years 2007 - 2023', fontsize=16, fontweight='bold')
##plt.ylabel(' ')
plt.xticks(rotation=90)
#plt.savefig('totals_bar_plot5.png',bbox_inches = 'tight', transparent=True)
plt.show;

# %% [markdown]
# 3PLOT VISITOR TOTAL FOR THE TOP 5 AND BOTTOM 5 PARKS

# %%
Top_five_parkpop=Intermountain_parkpop.groupby('park')['Visitors(1000s)'].mean().sort_values(ascending = False).head()
Top_five_parkpop=Top_five_parkpop.reset_index()

# %%
Top_five_parkpop.head()
# Out:
#                            park  Visitors(1000s)
# 0    Grand Canyon National Park      4859.470588
# 1     Yellowstone National Park      3750.588235
# 2  Rocky Mountain National Park      3693.529412
# 3            Zion National Park      3632.235294
# 4     Grand Teton National Park      3007.529412

# %%
Top_five_parkpop['Rank']='Top 5'
Top_five_parkpop
# Out:
#                            park  Visitors(1000s)   Rank
# 0    Grand Canyon National Park      4859.470588  Top 5
# 1     Yellowstone National Park      3750.588235  Top 5
# 2  Rocky Mountain National Park      3693.529412  Top 5
# 3            Zion National Park      3632.235294  Top 5
# 4     Grand Teton National Park      3007.529412  Top 5

# %%
Bottom_five_parkpop=Intermountain_parkpop.groupby('park')['Visitors(1000s)'].mean().sort_values(ascending = False).tail()
Bottom_five_parkpop=Bottom_five_parkpop.to_frame().reset_index()
Bottom_five_parkpop.head()
# Out:
#                                          park  Visitors(1000s)
# 0              Carlsbad Caverns National Park       403.647059
# 1                      Big Bend National Park       403.588235
# 2   Great Sand Dunes National Park & Preserve       376.352941
# 3  Black Canyon Of The Gunnison National Park       249.882353
# 4           Guadalupe Mountains National Park       183.764706

# %%
Bottom_five_parkpop['Rank']='Bottom 5'
Bottom_five_parkpop
# Out:
#                                          park  Visitors(1000s)      Rank
# 0              Carlsbad Caverns National Park       403.647059  Bottom 5
# 1                      Big Bend National Park       403.588235  Bottom 5
# 2   Great Sand Dunes National Park & Preserve       376.352941  Bottom 5
# 3  Black Canyon Of The Gunnison National Park       249.882353  Bottom 5
# 4           Guadalupe Mountains National Park       183.764706  Bottom 5

# %%
top_and_bottom_5=pd.concat([Top_five_parkpop,Bottom_five_parkpop])
top_and_bottom_5
# Out:
#                                          park  Visitors(1000s)      Rank
# 0                  Grand Canyon National Park      4859.470588     Top 5
# 1                   Yellowstone National Park      3750.588235     Top 5
# 2                Rocky Mountain National Park      3693.529412     Top 5
# 3                          Zion National Park      3632.235294     Top 5
# 4                   Grand Teton National Park      3007.529412     Top 5
# 0              Carlsbad Caverns National Park       403.647059  Bottom 5
# 1                      Big Bend National Park       403.588235  Bottom 5
# 2   Great Sand Dunes National Park & Preserve       376.352941  Bottom 5
# 3  Black Canyon Of The Gunnison National Park       249.882353  Bottom 5
# 4           Guadalupe Mountains National Park       183.764706  Bottom 5

# %%
plt.figure(figsize = (10,6))
top_and_bottom_5.sort_values('Visitors(1000s)',ascending=False).plot.bar('park', 'Visitors(1000s)')




ci=None
color='darkgreen'
plt.xticks(rotation=90)
plt.title('Top and Bottom 5 Park Visitor Totals')
plt.ylabel('Visitors(1000s)')
#plt.savefig('totals_bar_plot.png',bbox_inches = 'tight', transparent=True)
plt.show();

# %% [markdown]
# ##Wanting blue/green separation back##
#
# plt.figure(figsize = (10,6))
#
#
# mask1 = 'Visitors(1000s)' >'20000'
# mask2 = 'Visitors(1000s)' <'20000'
#
# top_and_bottom_5.sort_values('Visitors(1000s)',ascending=False).plot.bar('park'[mask1], 'Visitors(1000s)'[mask1], color = ('green'))
# top_and_bottom_5.sort_values('Visitors(1000s)',ascending=False).plot.bar('park'[mask2], 'Visitors(1000s)'[mask2], color = ('blue'))
# ci=None
# plt.xticks(rotation=90)
# plt.show()

# %%
nps_deaths.head(1)
# Out:
#   Incident Date                             Park Name Cause of Death  \
# 0      1/1/2007  Glen Canyon National Recreation Area   Undetermined
#
#   Cause of Death Group \n(Used in the NPS Mortality Dashboard)         Intent  \
# 0                                       Undetermined             Undetermined
#
#         Outcome   Sex Age Range      Activity
# 0  Fatal injury  Male       65+  Not Reported

# %% [markdown]
# CLEAN UP FOR CONSISTENCY IN PARK NAME

# %%
List=['Grand Canyon National Park','Yellowstone National Park','Rocky Mountain National Park','Zion National Park','Grand Teton National Park',
      'Carlsbad Caverns National Park','Big Bend National Park','Great Sand Dunes National Park & Preserve','Black Canyon Of The Gunnison National Park',
      'Guadalupe Mountains National Park']

# %%
List2=['Grand Canyon National Park','Yellowstone National Park','Rocky Mountain National Park','Zion National Park','Grand Teton National Park',
      'Carlsbad Caverns National Park','Big Bend National Park','Great Sand Dunes National Park & Preserve','Black Canyon Of The Gunnison National Park',
      'Guadalupe Mountains National Park','Arches National Park','Bryce Canyon National Park','Canyonlands National Park','Glacier National Park',
      'Grand Canyon National Park','Mesa Verde National Park','Petrified Forest National Park','Saguaro National Park','White Sands National Park']

# %%
new_nps_deaths=nps_deaths.loc[nps_deaths['Park Name'].isin(List2)]
new_nps_deaths
# Out:
#      Incident Date                                   Park Name  \
# 6        2/10/2007  Black Canyon Of The Gunnison National Park
# 20       3/31/2007                  Grand Canyon National Park
# 21        4/2/2007                  Grand Canyon National Park
# 32       4/30/2007                   Grand Teton National Park
# 33       4/30/2007                   Grand Teton National Park
# ...            ...                                         ...
# 4592     5/10/2024                  Grand Canyon National Park
# 4611      6/7/2024                  Bryce Canyon National Park
# 4621     6/16/2024                  Grand Canyon National Park
# 4622     6/17/2024                  Grand Canyon National Park
# 4633     6/29/2024                  Grand Canyon National Park
#
#                               Cause of Death  \
# 6                                       Fall
# 20                                  Drowning
# 21                                      Fall
# 32                                      Fall
# 33                                      Fall
# ...                                      ...
# 4592                                 Suicide
# 4611                                    Fall
# 4621                            Undetermined
# 4622  Medical - Not during physical activity
# 4633                            Undetermined
#
#      Cause of Death Group \n(Used in the NPS Mortality Dashboard)   \
# 6                                                  Fall
# 20                                             Drowning
# 21                                                 Fall
# 32                                                 Fall
# 33                                                 Fall
# ...                                                 ...
# 4592                                            Suicide
# 4611                                               Fall
# 4621                                       Undetermined
# 4622             Medical - Not during physical activity
# 4633                                       Undetermined
#
#              Intent       Outcome           Sex     Age Range        Activity
# 6     Unintentional  Fatal injury        Female         15-24    Not Reported
# 20    Unintentional  Fatal injury          Male         55-64  Vessel Related
# 21    Unintentional  Fatal injury          Male  Not Reported    Not Reported
# 32    Unintentional  Fatal injury          Male         25-34        Climbing
# 33    Unintentional  Fatal injury          Male         35-44        Climbing
# ...             ...           ...           ...           ...             ...
# 4592    Intentional  Fatal Injury          Male         55-64         Suicide
# 4611  Unintentional  Fatal Injury  Not Reported           65+         Walking
# 4621   Undetermined  Fatal Injury          Male         35-44          Hiking
# 4622        Medical  Fatal Injury          Male           65+        Sleeping
# 4633   Undetermined  Fatal Injury          Male         45-54          Hiking
#
# [698 rows x 9 columns]

# %%
new_10_nps_deaths=nps_deaths.loc[nps_deaths['Park Name'].isin(List)]
new_10_nps_deaths
# Out:
#      Incident Date                                   Park Name  \
# 6        2/10/2007  Black Canyon Of The Gunnison National Park
# 20       3/31/2007                  Grand Canyon National Park
# 21        4/2/2007                  Grand Canyon National Park
# 32       4/30/2007                   Grand Teton National Park
# 33       4/30/2007                   Grand Teton National Park
# ...            ...                                         ...
# 4571     4/11/2024              Carlsbad Caverns National Park
# 4592     5/10/2024                  Grand Canyon National Park
# 4621     6/16/2024                  Grand Canyon National Park
# 4622     6/17/2024                  Grand Canyon National Park
# 4633     6/29/2024                  Grand Canyon National Park
#
#                               Cause of Death  \
# 6                                       Fall
# 20                                  Drowning
# 21                                      Fall
# 32                                      Fall
# 33                                      Fall
# ...                                      ...
# 4571                            Undetermined
# 4592                                 Suicide
# 4621                            Undetermined
# 4622  Medical - Not during physical activity
# 4633                            Undetermined
#
#      Cause of Death Group \n(Used in the NPS Mortality Dashboard)   \
# 6                                                  Fall
# 20                                             Drowning
# 21                                                 Fall
# 32                                                 Fall
# 33                                                 Fall
# ...                                                 ...
# 4571                                       Undetermined
# 4592                                            Suicide
# 4621                                       Undetermined
# 4622             Medical - Not during physical activity
# 4633                                       Undetermined
#
#              Intent       Outcome           Sex     Age Range        Activity
# 6     Unintentional  Fatal injury        Female         15-24    Not Reported
# 20    Unintentional  Fatal injury          Male         55-64  Vessel Related
# 21    Unintentional  Fatal injury          Male  Not Reported    Not Reported
# 32    Unintentional  Fatal injury          Male         25-34        Climbing
# 33    Unintentional  Fatal injury          Male         35-44        Climbing
# ...             ...           ...           ...           ...             ...
# 4571   Undetermined  Fatal Injury  Not Reported           65+    Not Reported
# 4592    Intentional  Fatal Injury          Male         55-64         Suicide
# 4621   Undetermined  Fatal Injury          Male         35-44          Hiking
# 4622        Medical  Fatal Injury          Male           65+        Sleeping
# 4633   Undetermined  Fatal Injury          Male         45-54          Hiking
#
# [564 rows x 9 columns]

# %%
new_10_nps_deaths['Age Range']=new_nps_deaths['Age Range'].str.replace('35 - 44','35-44')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\1681782689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_10_nps_deaths['Age Range']=new_nps_deaths['Age Range'].str.replace('35 - 44','35-44')

# %%
new_nps_deaths['Age Range']=new_nps_deaths['Age Range'].str.replace('35 - 44','35-44')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\1997215723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_nps_deaths['Age Range']=new_nps_deaths['Age Range'].str.replace('35 - 44','35-44')

# %%
new_nps_deaths['Outcome']=new_nps_deaths['Outcome'].str.title()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\2207369093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_nps_deaths['Outcome']=new_nps_deaths['Outcome'].str.title()

# %%
new_nps_deaths
# Out:
#      Incident Date                                   Park Name  \
# 6        2/10/2007  Black Canyon Of The Gunnison National Park
# 20       3/31/2007                  Grand Canyon National Park
# 21        4/2/2007                  Grand Canyon National Park
# 32       4/30/2007                   Grand Teton National Park
# 33       4/30/2007                   Grand Teton National Park
# ...            ...                                         ...
# 4592     5/10/2024                  Grand Canyon National Park
# 4611      6/7/2024                  Bryce Canyon National Park
# 4621     6/16/2024                  Grand Canyon National Park
# 4622     6/17/2024                  Grand Canyon National Park
# 4633     6/29/2024                  Grand Canyon National Park
#
#                               Cause of Death  \
# 6                                       Fall
# 20                                  Drowning
# 21                                      Fall
# 32                                      Fall
# 33                                      Fall
# ...                                      ...
# 4592                                 Suicide
# 4611                                    Fall
# 4621                            Undetermined
# 4622  Medical - Not during physical activity
# 4633                            Undetermined
#
#      Cause of Death Group \n(Used in the NPS Mortality Dashboard)   \
# 6                                                  Fall
# 20                                             Drowning
# 21                                                 Fall
# 32                                                 Fall
# 33                                                 Fall
# ...                                                 ...
# 4592                                            Suicide
# 4611                                               Fall
# 4621                                       Undetermined
# 4622             Medical - Not during physical activity
# 4633                                       Undetermined
#
#              Intent       Outcome           Sex     Age Range        Activity
# 6     Unintentional  Fatal Injury        Female         15-24    Not Reported
# 20    Unintentional  Fatal Injury          Male         55-64  Vessel Related
# 21    Unintentional  Fatal Injury          Male  Not Reported    Not Reported
# 32    Unintentional  Fatal Injury          Male         25-34        Climbing
# 33    Unintentional  Fatal Injury          Male         35-44        Climbing
# ...             ...           ...           ...           ...             ...
# 4592    Intentional  Fatal Injury          Male         55-64         Suicide
# 4611  Unintentional  Fatal Injury  Not Reported           65+         Walking
# 4621   Undetermined  Fatal Injury          Male         35-44          Hiking
# 4622        Medical  Fatal Injury          Male           65+        Sleeping
# 4633   Undetermined  Fatal Injury          Male         45-54          Hiking
#
# [698 rows x 9 columns]

# %%
Deaths_per_age=new_nps_deaths.groupby('Sex')['Age Range'].value_counts().to_frame().reset_index()
Deaths_per_age
# Out:
#              Sex     Age Range  count
# 0         Female         55-64     29
# 1         Female         25-34     23
# 2         Female           65+     22
# 3         Female         45-54     21
# 4         Female         15-24     20
# 5         Female         35-44     15
# 6         Female  Not Reported     12
# 7         Female          0-14      6
# 8           Male           65+    126
# 9           Male         55-64     99
# 10          Male         25-34     79
# 11          Male         35-44     72
# 12          Male         15-24     57
# 13          Male         45-54     56
# 14          Male  Not Reported     31
# 15          Male          0-14      3
# 16  Not Reported  Not Reported     20
# 17  Not Reported           65+      3
# 18  Not Reported         15-24      2

# %%
new_10_nps_deaths['Sex']=new_10_nps_deaths['Sex'].str.replace('Not Reported','Unknown-Sex')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\997323218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_10_nps_deaths['Sex']=new_10_nps_deaths['Sex'].str.replace('Not Reported','Unknown-Sex')

# %%
Deaths_per_age['Sex']=Deaths_per_age['Sex'].str.replace('Not Reported','Unknown-Sex')

# %%
new_10_nps_deaths['Age Range']=new_10_nps_deaths['Age Range'].str.replace('Not Reported','Unknown-Age')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\2509543606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_10_nps_deaths['Age Range']=new_10_nps_deaths['Age Range'].str.replace('Not Reported','Unknown-Age')

# %%
Deaths_per_age['Age Range']=Deaths_per_age['Age Range'].str.replace('Not Reported','Unknown-Age')

# %%
Deaths_per_age.loc[Deaths_per_age['Age Range']=='Unknown']
# Out:
# Empty DataFrame
# Columns: [Sex, Age Range, count]
# Index: []

# %%
Deaths_per_age
# Out:
#             Sex    Age Range  count
# 0        Female        55-64     29
# 1        Female        25-34     23
# 2        Female          65+     22
# 3        Female        45-54     21
# 4        Female        15-24     20
# 5        Female        35-44     15
# 6        Female  Unknown-Age     12
# 7        Female         0-14      6
# 8          Male          65+    126
# 9          Male        55-64     99
# 10         Male        25-34     79
# 11         Male        35-44     72
# 12         Male        15-24     57
# 13         Male        45-54     56
# 14         Male  Unknown-Age     31
# 15         Male         0-14      3
# 16  Unknown-Sex  Unknown-Age     20
# 17  Unknown-Sex          65+      3
# 18  Unknown-Sex        15-24      2

# %%
pivot_Deaths_per_age=Deaths_per_age.pivot_table(index='Age Range',columns='Sex',values='count',aggfunc='sum')
pivot_Deaths_per_age.plot(kind='bar',stacked=False,figsize=(10,6), color=['darkgreen','darkblue','black'])
plt.title('Fatalities in the National Parks Comparing Age and Gender', fontsize=15, fontweight='bold')
plt.xlabel( 'Age Range',fontsize=15 )
#plt.ylabel('Number of Fatalities',fontsize=15,)
ax.set_title('fancy, transparent legends')
plt.legend(framealpha=0)
#plt.savefig('totals_bar_plot3.png',bbox_inches = 'tight', transparent=True)
plt.show()

# %%
Deaths_per_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sex        19 non-null     object
#  1   Age Range  19 non-null     object
#  2   count      19 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 588.0+ bytes

# %%
Deaths_per_gender=new_nps_deaths['Sex'].value_counts().to_frame().reset_index()
Deaths_per_gender
# Out:
#             Sex  count
# 0          Male    524
# 1        Female    148
# 2  Not Reported     26

# %% [markdown]
# combined_df=pd.concat([Deaths_per_age,Deaths_per_gender],axis=1)
# combined_df

# %%
new_10_nps_deaths['Incident Date'] = pd.to_datetime(new_nps_deaths['Incident Date'])
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\1578177735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_10_nps_deaths['Incident Date'] = pd.to_datetime(new_nps_deaths['Incident Date'])

# %%
new_nps_deaths['Incident Date'] = pd.to_datetime(new_nps_deaths['Incident Date'])
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\2600631922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_nps_deaths['Incident Date'] = pd.to_datetime(new_nps_deaths['Incident Date'])

# %%
new_10_nps_deaths['month']=new_nps_deaths['Incident Date'].dt.month
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\731457117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_10_nps_deaths['month']=new_nps_deaths['Incident Date'].dt.month

# %%
new_nps_deaths['month']=new_nps_deaths['Incident Date'].dt.month
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\1133000966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_nps_deaths['month']=new_nps_deaths['Incident Date'].dt.month

# %%
new_nps_deaths.head(1)
# Out:
#   Incident Date                                   Park Name Cause of Death  \
# 6    2007-02-10  Black Canyon Of The Gunnison National Park           Fall
#
#   Cause of Death Group \n(Used in the NPS Mortality Dashboard)   \
# 6                                               Fall
#
#           Intent       Outcome     Sex Age Range      Activity  month
# 6  Unintentional  Fatal Injury  Female     15-24  Not Reported      2

# %%
new_10_nps_deaths=new_nps_deaths.drop(columns=['Cause of Death Group \n(Used in the NPS Mortality Dashboard) '])

# %%
new_nps_deaths=new_nps_deaths.drop(columns=['Cause of Death Group \n(Used in the NPS Mortality Dashboard) '])

# %%
Causes_of_Death=new_nps_deaths['Cause of Death'].value_counts().to_frame().reset_index()
Causes_of_Death.head(30)
# Out:
#                             Cause of Death  count
# 0                                     Fall    174
# 1   Medical - Not during physical activity     77
# 2       Medical - During physical activity     73
# 3                             Undetermined     72
# 4                                  Suicide     66
# 5                      Motor Vehicle Crash     52
# 6                                 Drowning     52
# 7                             Hyperthermia     43
# 8                                Avalanche     17
# 9                        Medical - Unknown     16
# 10                             Flash flood     10
# 11                             Hypothermia     10
# 12                      Aircraft Incident       5
# 13                       Widlife incident       4
# 14                        Lightning Strike      3
# 15                         Skiing Incident      3
# 16                       Aircraft incident      2
# 17                         Vessel Incident      2
# 18                                Rockfall      2
# 19                        Lightning strike      2
# 20                       Poisoning - Drugs      2
# 21                                Homicide      2
# 22                       Poisoning - drugs      1
# 23                     Poisoning - alcohol      1
# 24                      Snowboard Incident      1
# 25               Horseback riding incident      1
# 26                     Falling tree/branch      1
# 27             Poisoning - Carbon monoxide      1
# 28                                 Firearm      1
# 29                      Bicycle only crash      1

# %%
new_nps_deaths.groupby(['Cause of Death','Park Name','Incident Date'])['Activity'].count().to_frame().reset_index()
# Out:
#          Cause of Death                     Park Name Incident Date  Activity
# 0    Aircraft Incident      Canyonlands National Park    2008-06-02         2
# 1    Aircraft Incident      Grand Teton National Park    2012-02-15         1
# 2    Aircraft Incident      Grand Teton National Park    2013-09-11         2
# 3     Aircraft incident     Grand Teton National Park    2018-06-09         2
# 4          Asphyxiation  Rocky Mountain National Park    2022-05-19         1
# ..                  ...                           ...           ...       ...
# 652     Vessel Incident     Grand Teton National Park    2014-09-04         1
# 653   Widlife incident      Grand Teton National Park    2018-09-14         1
# 654   Widlife incident      Yellowstone National Park    2011-07-06         1
# 655   Widlife incident      Yellowstone National Park    2011-08-26         1
# 656   Widlife incident      Yellowstone National Park    2015-08-10         1
#
# [657 rows x 4 columns]

# %%
new_nps_deaths.head(1)
# Out:
#   Incident Date                                   Park Name Cause of Death  \
# 6    2007-02-10  Black Canyon Of The Gunnison National Park           Fall
#
#           Intent       Outcome     Sex Age Range      Activity  month
# 6  Unintentional  Fatal Injury  Female     15-24  Not Reported      2

# %%
new_nps_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 698 entries, 6 to 4633
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Incident Date   698 non-null    datetime64[ns]
#  1   Park Name       698 non-null    object
#  2   Cause of Death  698 non-null    object
#  3   Intent          698 non-null    object
#  4   Outcome         698 non-null    object
#  5   Sex             698 non-null    object
#  6   Age Range       696 non-null    object
#  7   Activity        698 non-null    object
#  8   month           698 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(7)
# memory usage: 68.0+ KB

# %%
Intermountain_parkpop.head(1)
# Out:
#     Year  Visitors(1000s)                      park
# 99  2007            541.0  Mesa Verde National Park

# %%
new_nps_deaths['month']=new_nps_deaths['Incident Date'].dt.month

# %%
new_nps_deaths.head(1)
# Out:
#   Incident Date                                   Park Name Cause of Death  \
# 6    2007-02-10  Black Canyon Of The Gunnison National Park           Fall
#
#           Intent       Outcome     Sex Age Range      Activity  month
# 6  Unintentional  Fatal Injury  Female     15-24  Not Reported      2

# %%
new_10_nps_deaths['year']=new_nps_deaths['Incident Date'].dt.year
new_10_nps_deaths.head(1)
# Out:
#   Incident Date                                   Park Name Cause of Death  \
# 6    2007-02-10  Black Canyon Of The Gunnison National Park           Fall
#
#           Intent       Outcome     Sex Age Range      Activity  month  year
# 6  Unintentional  Fatal Injury  Female     15-24  Not Reported      2  2007

# %%
new_nps_deaths['year']=new_nps_deaths['Incident Date'].dt.year
new_nps_deaths.head(1)
# Out:
#   Incident Date                                   Park Name Cause of Death  \
# 6    2007-02-10  Black Canyon Of The Gunnison National Park           Fall
#
#           Intent       Outcome     Sex Age Range      Activity  month  year
# 6  Unintentional  Fatal Injury  Female     15-24  Not Reported      2  2007

# %%
Intermountain_parkpop=Intermountain_parkpop.rename(columns={'park':'Park Name'})
Intermountain_parkpop.head()
# Out:
#      Year  Visitors(1000s)                 Park Name
# 99   2007            541.0  Mesa Verde National Park
# 100  2008            551.0  Mesa Verde National Park
# 101  2009            550.0  Mesa Verde National Park
# 102  2010            560.0  Mesa Verde National Park
# 103  2011            572.0  Mesa Verde National Park

# %%
new_nps_deaths=new_nps_deaths.drop(columns=['Incident Date']).rename(columns={'year':'Year'})

# %% [markdown]
# Combine population and death data

# %%
####Watch the fact you almost combined only the top and bottom 5 parks for the rest of the calculations###
##have new_10_nps_deaths and new_nps_deaths for all parks

# %%
deaths_population=pd.merge(new_nps_deaths, Intermountain_parkpop, 
                               left_on = ['Year', 'Park Name'], right_on = ['Year', 'Park Name'],
                               how = 'inner')
deaths_population.head()
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
# 1                  Grand Canyon National Park       Drowning  Unintentional
# 2                  Grand Canyon National Park           Fall  Unintentional
# 3                   Grand Teton National Park           Fall  Unintentional
# 4                   Grand Teton National Park           Fall  Unintentional
#
#         Outcome     Sex     Age Range        Activity  month  Year  \
# 0  Fatal Injury  Female         15-24    Not Reported      2  2007
# 1  Fatal Injury    Male         55-64  Vessel Related      3  2007
# 2  Fatal Injury    Male  Not Reported    Not Reported      4  2007
# 3  Fatal Injury    Male         25-34        Climbing      4  2007
# 4  Fatal Injury    Male         35-44        Climbing      4  2007
#
#    Visitors(1000s)
# 0            220.0
# 1           4414.0
# 2           4414.0
# 3           2589.0
# 4           2589.0

# %% [markdown]
# Death trend from 2007 to 2023/ parks and casues

# %%
deaths_population.to_csv('deaths_population.csv', index=False)

# %%
deaths_population_2007=deaths_population.loc[deaths_population['Year']==2007]

# %%
deaths_population['Park Name'].unique()
# Out:
# array(['Black Canyon Of The Gunnison National Park',
#        'Grand Canyon National Park', 'Grand Teton National Park',
#        'Zion National Park', 'Yellowstone National Park',
#        'Rocky Mountain National Park', 'Canyonlands National Park',
#        'Saguaro National Park', 'Glacier National Park',
#        'Big Bend National Park',
#        'Great Sand Dunes National Park & Preserve',
#        'White Sands National Park', 'Bryce Canyon National Park',
#        'Mesa Verde National Park', 'Guadalupe Mountains National Park',
#        'Arches National Park', 'Carlsbad Caverns National Park',
#        'Petrified Forest National Park'], dtype=object)

# %%
deaths_population_2007.groupby('Park Name')['Outcome'].count().reset_index()
# Out:
#                                     Park Name  Outcome
# 0  Black Canyon Of The Gunnison National Park        1
# 1                  Grand Canyon National Park        6
# 2                   Grand Teton National Park        3
# 3                Rocky Mountain National Park        1
# 4                   Yellowstone National Park        6
# 5                          Zion National Park        2

# %%
deaths_population_2015=deaths_population.loc[deaths_population['Year']==2015]

# %%
deaths_population_2015.groupby('Cause of Death').count().reset_index()
# Out:
#                             Cause of Death  Park Name  Intent  Outcome  Sex  \
# 0                                Avalanche          2       2        2    2
# 1                                 Drowning          2       2        2    2
# 2                                     Fall          9       9        9    9
# 3                              Flash flood          7       7        7    7
# 4                             Hyperthermia          6       6        6    6
# 5                              Hypothermia          1       1        1    1
# 6                         Lightning Strike          1       1        1    1
# 7       Medical - During physical activity          5       5        5    5
# 8   Medical - Not during physical activity          6       6        6    6
# 9                        Medical - Unknown          1       1        1    1
# 10                     Motor Vehicle Crash          5       5        5    5
# 11                                 Suicide          6       6        6    6
# 12                            Undetermined          3       3        3    3
# 13                       Widlife incident           1       1        1    1
#
#     Age Range  Activity  month  Year  Visitors(1000s)
# 0           2         2      2     2                2
# 1           2         2      2     2                2
# 2           9         9      9     9                9
# 3           7         7      7     7                7
# 4           6         6      6     6                6
# 5           1         1      1     1                1
# 6           1         1      1     1                1
# 7           5         5      5     5                5
# 8           6         6      6     6                6
# 9           1         1      1     1                1
# 10          5         5      5     5                5
# 11          6         6      6     6                6
# 12          3         3      3     3                3
# 13          1         1      1     1                1

# %%
deaths_population_2015.groupby('Park Name')['Outcome'].count().reset_index()
# Out:
#                             Park Name  Outcome
# 0          Bryce Canyon National Park        1
# 1           Canyonlands National Park        4
# 2               Glacier National Park        3
# 3          Grand Canyon National Park       14
# 4           Grand Teton National Park        4
# 5   Guadalupe Mountains National Park        3
# 6        Rocky Mountain National Park        2
# 7               Saguaro National Park        1
# 8           White Sands National Park        2
# 9           Yellowstone National Park       11
# 10                 Zion National Park       10

# %%
deaths_population_2007.groupby('Cause of Death').count().reset_index()
# Out:
#         Cause of Death  Park Name  Intent  Outcome  Sex  Age Range  Activity  \
# 0             Drowning          3       3        3    3          3         3
# 1                 Fall         10      10       10   10         10        10
# 2  Motor Vehicle Crash          4       4        4    4          4         4
# 3         Undetermined          2       2        2    2          2         2
#
#    month  Year  Visitors(1000s)
# 0      3     3                3
# 1     10    10               10
# 2      4     4                4
# 3      2     2                2

# %%
deaths_population_2023=deaths_population.loc[deaths_population['Year']==2023]

# %%
deaths_population_2023.groupby('Park Name')['Outcome'].count().reset_index()
# Out:
#                            Park Name  Outcome
# 0               Arches National Park        4
# 1             Big Bend National Park        9
# 2         Bryce Canyon National Park        2
# 3          Canyonlands National Park        1
# 4              Glacier National Park        1
# 5         Grand Canyon National Park        5
# 6          Grand Teton National Park        3
# 7  Guadalupe Mountains National Park        1
# 8       Rocky Mountain National Park        3
# 9          Yellowstone National Park        3

# %%
deaths_population_2023.groupby('Cause of Death').count().reset_index()
# Out:
#                            Cause of Death  Park Name  Intent  Outcome  Sex  \
# 0                                Drowning          1       1        1    1
# 1                                    Fall          6       6        6    6
# 2                             Flash flood          1       1        1    1
# 3                                Homicide          1       1        1    1
# 4                            Hyperthermia          4       4        4    4
# 5      Medical - During physical activity          2       2        2    2
# 6  Medical - Not during physical activity          1       1        1    1
# 7                     Motor Vehicle Crash          2       2        2    2
# 8                                 Suicide          2       2        2    2
# 9                            Undetermined         12      12       12   12
#
#    Age Range  Activity  month  Year  Visitors(1000s)
# 0          1         1      1     1                1
# 1          6         6      6     6                6
# 2          1         1      1     1                1
# 3          1         1      1     1                1
# 4          4         4      4     4                4
# 5          2         2      2     2                2
# 6          1         1      1     1                1
# 7          2         2      2     2                2
# 8          2         2      2     2                2
# 9         12        12     12    12               12

# %%
deaths_population.shape
# Out:
# (692, 10)

# %% [markdown]
# Visitors: min and max per 1000

# %%
deaths_population['Visitors(1000s)'].min()
# Out:
# 170.0

# %%
deaths_population['Visitors(1000s)'].max()
# Out:
# 6380.0

# %%
deaths_population.head(5)
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
# 1                  Grand Canyon National Park       Drowning  Unintentional
# 2                  Grand Canyon National Park           Fall  Unintentional
# 3                   Grand Teton National Park           Fall  Unintentional
# 4                   Grand Teton National Park           Fall  Unintentional
#
#         Outcome     Sex     Age Range        Activity  month  Year  \
# 0  Fatal Injury  Female         15-24    Not Reported      2  2007
# 1  Fatal Injury    Male         55-64  Vessel Related      3  2007
# 2  Fatal Injury    Male  Not Reported    Not Reported      4  2007
# 3  Fatal Injury    Male         25-34        Climbing      4  2007
# 4  Fatal Injury    Male         35-44        Climbing      4  2007
#
#    Visitors(1000s)
# 0            220.0
# 1           4414.0
# 2           4414.0
# 3           2589.0
# 4           2589.0

# %%
Park_Visitors_totals=deaths_population.drop(columns=['Cause of Death','Intent','Outcome','Sex','Age Range','Activity','month','Year'])
Park_Visitors_totals=Park_Visitors_totals.drop_duplicates(subset='Park Name')

# %%
Park_Visitors_totals.plot(kind='bar',
                      x='Park Name',
                      y='Visitors(1000s)')
plt.title('Total Visitors by Park')
plt.xlabel('Park Name')
plt.ylabel('Visitors(1000s)')
#plt.savefig('visitors by park5',bbox_inches = 'tight', transparent=True)
plt.show()

# %%
deaths_population.head(1)
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
#
#         Outcome     Sex Age Range      Activity  month  Year  Visitors(1000s)
# 0  Fatal Injury  Female     15-24  Not Reported      2  2007            220.0

# %%
Deaths_per_park=deaths_population.groupby(['Park Name','Cause of Death','Year'])['Outcome'].count().to_frame().reset_index().rename(columns={'Outcome':'Fatality_Count'})
Deaths_per_park
# Out:
#                 Park Name                          Cause of Death  Year  \
# 0    Arches National Park                                    Fall  2019
# 1    Arches National Park                                    Fall  2022
# 2    Arches National Park                            Hyperthermia  2016
# 3    Arches National Park                            Hyperthermia  2018
# 4    Arches National Park                            Hyperthermia  2021
# ..                    ...                                     ...   ...
# 422    Zion National Park  Medical - Not during physical activity  2022
# 423    Zion National Park                                 Suicide  2017
# 424    Zion National Park                                 Suicide  2021
# 425    Zion National Park                            Undetermined  2010
# 426    Zion National Park                            Undetermined  2021
#
#      Fatality_Count
# 0                 2
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 422               1
# 423               1
# 424               2
# 425               2
# 426               1
#
# [427 rows x 4 columns]

# %% [markdown]
# FIND TOTAL DEATHS PER CAPITAL OF MILLION AND THEN CAUSE OF DEATH TOTAL PER CAPITA PER PARK

# %%
Total_deaths=deaths_population.groupby(['Park Name','Year'])['Outcome'].count().reset_index().rename(columns={'Outcome':'Total Deaths'})
Total_deaths
# Out:
#                 Park Name  Year  Total Deaths
# 0    Arches National Park  2016             3
# 1    Arches National Park  2017             1
# 2    Arches National Park  2018             2
# 3    Arches National Park  2019             3
# 4    Arches National Park  2021             1
# ..                    ...   ...           ...
# 163    Zion National Park  2017             4
# 164    Zion National Park  2018             3
# 165    Zion National Park  2019             4
# 166    Zion National Park  2021             6
# 167    Zion National Park  2022             4
#
# [168 rows x 3 columns]

# %%
Total_deaths.groupby('Park Name')['Total Deaths'].sum().reset_index()
# Out:
#                                      Park Name  Total Deaths
# 0                         Arches National Park            15
# 1                       Big Bend National Park            35
# 2   Black Canyon Of The Gunnison National Park             9
# 3                   Bryce Canyon National Park             6
# 4                    Canyonlands National Park            27
# 5               Carlsbad Caverns National Park             3
# 6                        Glacier National Park            53
# 7                   Grand Canyon National Park           212
# 8                    Grand Teton National Park            73
# 9    Great Sand Dunes National Park & Preserve             4
# 10           Guadalupe Mountains National Park             7
# 11                    Mesa Verde National Park             5
# 12              Petrified Forest National Park             1
# 13                Rocky Mountain National Park            77
# 14                       Saguaro National Park            19
# 15                   White Sands National Park             7
# 16                   Yellowstone National Park            84
# 17                          Zion National Park            55

# %% [markdown]
# DO NOT LOOK AT ABOVE TABLE CLOSELY BC IT IS NOT WEIGHTED PER CAPITA

# %% [markdown]
# TOTAL DEATHS IN INTRAMOUNTAINOUS RANGE PARKS 2007-2023

# %%
Total_deaths['Total Deaths'].sum()
# Out:
# 692

# %% [markdown]
# BELOW SHOWS PARK FATALITIES PER CAUSE OF DEATH PER YEAR

# %%
Visitors_Fatality_merge=pd.merge(deaths_population, Deaths_per_park, left_on=['Park Name', 'Year', 'Cause of Death'],right_on=['Park Name','Year','Cause of Death'], how='inner')
Visitors_Fatality_merge
# Out:
#                                       Park Name  \
# 0    Black Canyon Of The Gunnison National Park
# 1                    Grand Canyon National Park
# 2                    Grand Canyon National Park
# 3                     Grand Teton National Park
# 4                     Grand Teton National Park
# ..                                          ...
# 687                  Bryce Canyon National Park
# 688                   Grand Teton National Park
# 689                  Bryce Canyon National Park
# 690                  Grand Canyon National Park
# 691                      Big Bend National Park
#
#                              Cause of Death         Intent       Outcome  \
# 0                                      Fall  Unintentional  Fatal Injury
# 1                                  Drowning  Unintentional  Fatal Injury
# 2                                      Fall  Unintentional  Fatal Injury
# 3                                      Fall  Unintentional  Fatal Injury
# 4                                      Fall  Unintentional  Fatal Injury
# ..                                      ...            ...           ...
# 687                             Flash flood  Unintentional  Fatal Injury
# 688                            Undetermined  Unintentional  Fatal Injury
# 689                            Undetermined   Undetermined  Fatal Injury
# 690                            Undetermined   Undetermined  Fatal Injury
# 691  Medical - Not during physical activity        Medical  Fatal Injury
#
#         Sex     Age Range        Activity  month  Year  Visitors(1000s)  \
# 0    Female         15-24    Not Reported      2  2007            220.0
# 1      Male         55-64  Vessel Related      3  2007           4414.0
# 2      Male  Not Reported    Not Reported      4  2007           4414.0
# 3      Male         25-34        Climbing      4  2007           2589.0
# 4      Male         35-44        Climbing      4  2007           2589.0
# ..      ...           ...             ...    ...   ...              ...
# 687  Female           65+          Hiking      8  2023           2461.0
# 688    Male           65+    Not Reported      9  2023           3417.0
# 689    Male           65+    Not Reported      9  2023           2461.0
# 690    Male           65+          Hiking     11  2023           4734.0
# 691    Male         35-44           Other     12  2023            509.0
#
#      Fatality_Count
# 0                 1
# 1                 1
# 2                 4
# 3                 2
# 4                 2
# ..              ...
# 687               1
# 688               1
# 689               1
# 690               3
# 691               1
#
# [692 rows x 11 columns]

# %%
Visitors_Fatality_merge['Visitors']=Visitors_Fatality_merge['Visitors(1000s)']*1000

# %%
Visitors_Fatality_merge.head()
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
# 1                  Grand Canyon National Park       Drowning  Unintentional
# 2                  Grand Canyon National Park           Fall  Unintentional
# 3                   Grand Teton National Park           Fall  Unintentional
# 4                   Grand Teton National Park           Fall  Unintentional
#
#         Outcome     Sex     Age Range        Activity  month  Year  \
# 0  Fatal Injury  Female         15-24    Not Reported      2  2007
# 1  Fatal Injury    Male         55-64  Vessel Related      3  2007
# 2  Fatal Injury    Male  Not Reported    Not Reported      4  2007
# 3  Fatal Injury    Male         25-34        Climbing      4  2007
# 4  Fatal Injury    Male         35-44        Climbing      4  2007
#
#    Visitors(1000s)  Fatality_Count   Visitors
# 0            220.0               1   220000.0
# 1           4414.0               1  4414000.0
# 2           4414.0               4  4414000.0
# 3           2589.0               2  2589000.0
# 4           2589.0               2  2589000.0

# %% [markdown]
# ##change to per capita in millions

# %%
Visitors_Fatality_merge.head()
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
# 1                  Grand Canyon National Park       Drowning  Unintentional
# 2                  Grand Canyon National Park           Fall  Unintentional
# 3                   Grand Teton National Park           Fall  Unintentional
# 4                   Grand Teton National Park           Fall  Unintentional
#
#         Outcome     Sex     Age Range        Activity  month  Year  \
# 0  Fatal Injury  Female         15-24    Not Reported      2  2007
# 1  Fatal Injury    Male         55-64  Vessel Related      3  2007
# 2  Fatal Injury    Male  Not Reported    Not Reported      4  2007
# 3  Fatal Injury    Male         25-34        Climbing      4  2007
# 4  Fatal Injury    Male         35-44        Climbing      4  2007
#
#    Visitors(1000s)  Fatality_Count   Visitors
# 0            220.0               1   220000.0
# 1           4414.0               1  4414000.0
# 2           4414.0               4  4414000.0
# 3           2589.0               2  2589000.0
# 4           2589.0               2  2589000.0

# %%
Visitors_Fatality_merge['Fatalities_per_million']=Visitors_Fatality_merge['Fatality_Count']/Visitors_Fatality_merge['Visitors'] *1000000
Visitors_Fatality_merge.head(1)
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
#
#         Outcome     Sex Age Range      Activity  month  Year  Visitors(1000s)  \
# 0  Fatal Injury  Female     15-24  Not Reported      2  2007            220.0
#
#    Fatality_Count  Visitors  Fatalities_per_million
# 0               1  220000.0                4.545455

# %% [markdown]
# Visitors_Fatality_merge['Fatalities_per_million']=Visitors_Fatality_merge['Fatality_Count']/Visitors_Fatality_merge['Visitors'] *1000000
# Visitors_Fatality_merge.head(30)

# %%
Visitors_Fatality_merge.groupby('Park Name')
Visitors_Fatality_merge.head()
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
# 1                  Grand Canyon National Park       Drowning  Unintentional
# 2                  Grand Canyon National Park           Fall  Unintentional
# 3                   Grand Teton National Park           Fall  Unintentional
# 4                   Grand Teton National Park           Fall  Unintentional
#
#         Outcome     Sex     Age Range        Activity  month  Year  \
# 0  Fatal Injury  Female         15-24    Not Reported      2  2007
# 1  Fatal Injury    Male         55-64  Vessel Related      3  2007
# 2  Fatal Injury    Male  Not Reported    Not Reported      4  2007
# 3  Fatal Injury    Male         25-34        Climbing      4  2007
# 4  Fatal Injury    Male         35-44        Climbing      4  2007
#
#    Visitors(1000s)  Fatality_Count   Visitors  Fatalities_per_million
# 0            220.0               1   220000.0                4.545455
# 1           4414.0               1  4414000.0                0.226552
# 2           4414.0               4  4414000.0                0.906208
# 3           2589.0               2  2589000.0                0.772499
# 4           2589.0               2  2589000.0                0.772499

# %% [markdown]
# ###########################################################################################################################
# Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Aircraft Incident ','Aircraft Incident')
# ###########################################################################################################################

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.title()
Visitors_Fatality_merge
# Out:
#                                       Park Name  \
# 0    Black Canyon Of The Gunnison National Park
# 1                    Grand Canyon National Park
# 2                    Grand Canyon National Park
# 3                     Grand Teton National Park
# 4                     Grand Teton National Park
# ..                                          ...
# 687                  Bryce Canyon National Park
# 688                   Grand Teton National Park
# 689                  Bryce Canyon National Park
# 690                  Grand Canyon National Park
# 691                      Big Bend National Park
#
#                              Cause of Death         Intent       Outcome  \
# 0                                      Fall  Unintentional  Fatal Injury
# 1                                  Drowning  Unintentional  Fatal Injury
# 2                                      Fall  Unintentional  Fatal Injury
# 3                                      Fall  Unintentional  Fatal Injury
# 4                                      Fall  Unintentional  Fatal Injury
# ..                                      ...            ...           ...
# 687                             Flash Flood  Unintentional  Fatal Injury
# 688                            Undetermined  Unintentional  Fatal Injury
# 689                            Undetermined   Undetermined  Fatal Injury
# 690                            Undetermined   Undetermined  Fatal Injury
# 691  Medical - Not During Physical Activity        Medical  Fatal Injury
#
#         Sex     Age Range        Activity  month  Year  Visitors(1000s)  \
# 0    Female         15-24    Not Reported      2  2007            220.0
# 1      Male         55-64  Vessel Related      3  2007           4414.0
# 2      Male  Not Reported    Not Reported      4  2007           4414.0
# 3      Male         25-34        Climbing      4  2007           2589.0
# 4      Male         35-44        Climbing      4  2007           2589.0
# ..      ...           ...             ...    ...   ...              ...
# 687  Female           65+          Hiking      8  2023           2461.0
# 688    Male           65+    Not Reported      9  2023           3417.0
# 689    Male           65+    Not Reported      9  2023           2461.0
# 690    Male           65+          Hiking     11  2023           4734.0
# 691    Male         35-44           Other     12  2023            509.0
#
#      Fatality_Count   Visitors  Fatalities_per_million
# 0                 1   220000.0                4.545455
# 1                 1  4414000.0                0.226552
# 2                 4  4414000.0                0.906208
# 3                 2  2589000.0                0.772499
# 4                 2  2589000.0                0.772499
# ..              ...        ...                     ...
# 687               1  2461000.0                0.406339
# 688               1  3417000.0                0.292654
# 689               1  2461000.0                0.406339
# 690               3  4734000.0                0.633714
# 691               1   509000.0                1.964637
#
# [692 rows x 13 columns]

# %% [markdown]
# Average fatalities per million per year

# %%
Visitors_Fatality_merge.groupby('Year')['Fatalities_per_million'].mean()
# Out:
# Year
# 2007    0.886766
# 2008    1.570930
# 2009    0.857780
# 2010    0.988386
# 2011    0.858448
# 2012    1.653258
# 2013    1.802620
# 2014    1.145644
# 2015    1.412891
# 2016    1.044063
# 2017    0.831234
# 2018    0.725506
# 2019    0.953779
# 2020    1.234295
# 2021    1.310184
# 2022    0.971260
# 2023    1.997667
# Name: Fatalities_per_million, dtype: float64

# %%
new_group=Visitors_Fatality_merge.groupby('Park Name')['Fatalities_per_million'].mean().reset_index()
new_group.head(18)
# Out:
#                                      Park Name  Fatalities_per_million
# 0                         Arches National Park                1.066789
# 1                       Big Bend National Park                4.054993
# 2   Black Canyon Of The Gunnison National Park                5.947342
# 3                   Bryce Canyon National Park                0.495075
# 4                    Canyonlands National Park                2.697197
# 5               Carlsbad Caverns National Park                3.519212
# 6                        Glacier National Park                0.699785
# 7                   Grand Canyon National Park                0.788882
# 8                    Grand Teton National Park                0.627547
# 9    Great Sand Dunes National Park & Preserve                2.823142
# 10           Guadalupe Mountains National Park                6.824105
# 11                    Mesa Verde National Park                1.834619
# 12              Petrified Forest National Park                1.980198
# 13                Rocky Mountain National Park                0.550337
# 14                       Saguaro National Park                2.408332
# 15                   White Sands National Park                2.317298
# 16                   Yellowstone National Park                0.474913
# 17                          Zion National Park                0.750386

# %% [markdown]
# new_group =new_Visitors_Fatality_merge.groupby('Park Name')['Fatalities_per_million'].mean().to_frame().reset_index()
# new_group.head(18)

# %%
Top_5_for_fatalities=new_group.sort_values('Fatalities_per_million', ascending=False).head()
Top_5_for_fatalities.head()
# Out:
#                                      Park Name  Fatalities_per_million
# 10           Guadalupe Mountains National Park                6.824105
# 2   Black Canyon Of The Gunnison National Park                5.947342
# 1                       Big Bend National Park                4.054993
# 5               Carlsbad Caverns National Park                3.519212
# 9    Great Sand Dunes National Park & Preserve                2.823142

# %%
Bottom_5_for_fatalities=new_group.sort_values('Fatalities_per_million', ascending=False).tail()
Bottom_5_for_fatalities
# Out:
#                        Park Name  Fatalities_per_million
# 6          Glacier National Park                0.699785
# 8      Grand Teton National Park                0.627547
# 13  Rocky Mountain National Park                0.550337
# 3     Bryce Canyon National Park                0.495075
# 16     Yellowstone National Park                0.474913

# %% [markdown]
# Fatalities /million from 2007 through 2023

# %%
Visitors_Fatality_merge['Fatalities_per_million'].mean()
# Out:
# 1.1613894831443219

# %%
plt.figure(figsize = (10,6))

ax=sns.barplot(data =new_group.sort_values('Fatalities_per_million', ascending=False),
               x = 'Fatalities_per_million',
               y = 'Park Name', color='darkgreen',         
                errorbar=None)


plt.title('Average Fatalities/Million Per Park: 2007 - 2023', fontsize=16, fontweight='bold')
##plt.ylabel(' ')
##plt.xlabel(' ')
#plt.savefig('fatalities_bar_plot',bbox_inches = 'tight', transparent=True)
plt.show;

# %%
plt.figure(figsize = (10,6))

sns.barplot(data =new_group.sort_values('Fatalities_per_million',ascending=False),
               x = 'Park Name',
               y = 'Fatalities_per_million', color='darkgreen',errorbar=None)       
                
plt.title('Fatalities per National Park', fontsize=16)
plt.ylabel('Fatalities', fontsize=14)
plt.xlabel(' ')
plt.xticks(rotation=90)
#plt.savefig('fatalities2_bar_plot5',bbox_inches = 'tight', transparent=True)
plt.show()

# %%
Top_and_bottom_for_fatalities=pd.concat([Top_5_for_fatalities, Bottom_5_for_fatalities])
Top_and_bottom_for_fatalities
# Out:
#                                      Park Name  Fatalities_per_million
# 10           Guadalupe Mountains National Park                6.824105
# 2   Black Canyon Of The Gunnison National Park                5.947342
# 1                       Big Bend National Park                4.054993
# 5               Carlsbad Caverns National Park                3.519212
# 9    Great Sand Dunes National Park & Preserve                2.823142
# 6                        Glacier National Park                0.699785
# 8                    Grand Teton National Park                0.627547
# 13                Rocky Mountain National Park                0.550337
# 3                   Bryce Canyon National Park                0.495075
# 16                   Yellowstone National Park                0.474913

# %%
import matplotlib.patches as mpatches

# %%
top_and_bottom_5.head(10)
# Out:
#                                          park  Visitors(1000s)      Rank
# 0                  Grand Canyon National Park      4859.470588     Top 5
# 1                   Yellowstone National Park      3750.588235     Top 5
# 2                Rocky Mountain National Park      3693.529412     Top 5
# 3                          Zion National Park      3632.235294     Top 5
# 4                   Grand Teton National Park      3007.529412     Top 5
# 0              Carlsbad Caverns National Park       403.647059  Bottom 5
# 1                      Big Bend National Park       403.588235  Bottom 5
# 2   Great Sand Dunes National Park & Preserve       376.352941  Bottom 5
# 3  Black Canyon Of The Gunnison National Park       249.882353  Bottom 5
# 4           Guadalupe Mountains National Park       183.764706  Bottom 5

# %%
plt.figure(figsize = (10,6))
top_and_bottom_5.sort_values('Visitors(1000s)',ascending=False).plot.bar('park', 'Visitors(1000s)', color='darkgreen')




ci=None
plt.xticks(rotation=90)
plt.title('Top and Bottom 5 Park Visitor Totals')
##plt.ylabel('Visitors(1000s)')
plt.legend(framealpha=0)
#plt.savefig('totals_bar_plot.png',bbox_inches = 'tight', transparent=True)
plt.show();

# %%
Top_and_bottom_for_fatalities.head(10)
# Out:
#                                      Park Name  Fatalities_per_million
# 10           Guadalupe Mountains National Park                6.824105
# 2   Black Canyon Of The Gunnison National Park                5.947342
# 1                       Big Bend National Park                4.054993
# 5               Carlsbad Caverns National Park                3.519212
# 9    Great Sand Dunes National Park & Preserve                2.823142
# 6                        Glacier National Park                0.699785
# 8                    Grand Teton National Park                0.627547
# 13                Rocky Mountain National Park                0.550337
# 3                   Bryce Canyon National Park                0.495075
# 16                   Yellowstone National Park                0.474913

# %%
plt.figure(figsize = (10,6))
Top_and_bottom_for_fatalities.sort_values('Fatalities_per_million',ascending=False).plot.bar('Park Name', 'Fatalities_per_million', color='darkblue')




ci=None
plt.xticks(rotation=90)
plt.title('Top and Bottom 5 Park Fatality Totals')
##plt.ylabel('Fatalities per Million')
plt.legend(framealpha=0)
#plt.savefig('fatalities_bar_plot2',bbox_inches = 'tight', transparent=True)
plt.show();

# %% [markdown]
# colors=[]
# for_, row in merged_df.iterrows():
#     if row['Rank']=='Top 5'
# and
# row['fatalities_per_million']>2:
#     colors.append('purple')
#
# elif row['Rank']== 'Bottom 5' and
# row['fatalities_per_million']<=2:
#     colors.append('orange')
# else:
#     colors.append('grey')
#
# fig, ax1=
# plt.subplots(figsize=(14,8))
#
# ax1.bar(x-width/2,merged_df['Visitors(1000s)'],width,label='Visitors(1000s)',color=colors)
# ax2=ax1.twinx()
# ax2.bar(x + width/2,merged_df['fatalities_per_million'],width,
# label='Fatalities_per_million',
# color='blue')
#
# ax1.set_xlabel('Park Name')
# ax1.set_ylabel('Visitors(1000s)',color='green')
# ax2.set_ylabel('Fatalities_per_million',color='blue')
# ax1.set_xticks(x)
# ax1.set_xticklabels(merged_df['park'], rotation=90)
# ax1.legend(loc='upper left')
# ax2.legend(loc='upper right')
#
# plt.title('Top and Bottom 5 Parks by Visitors and Fatalities with Color Coding')
# plt.tight_layout()
# plt.show()

# %%
top_parks = ['Guadalupe Mountains National Park','Black Canyon Of The Gunnison National Park','Big Bend National Park',
'Carlsbad Caverns National Park','Great Sand Dunes National Park & Preserve']

bottom_parks = ['Glacier National Park','Grand Teton National Park','Rocky Mountain National Park','Bryce Canyon National Park',
                'Yellowstone National Park']

Top_and_bottom_for_fatalities['Color'] = Top_and_bottom_for_fatalities['Park Name'].apply(
    lambda x: 'darkblue' if x in top_parks else 'darkgreen' if x in bottom_parks else 'grey')


fig, ax = plt.subplots(figsize=(10,6))
Top_and_bottom_for_fatalities.sort_values('Fatalities_per_million', ascending=False).plot.bar(
    x='Park Name', y='Fatalities_per_million', color=Top_and_bottom_for_fatalities['Color'], 
    legend=False,ax=ax)
ax.set_xlabel=(' ')
plt.xticks(rotation=90)
plt.ylabel('Fatalities per Million', fontsize=14)
plt.title('Top and Bottom 5 Parks for Fatalities', fontsize=16, fontweight='bold')
top_bar = mpatches.Patch(color='darkblue', label = 'Top 5 Parks')
bottom_bar = mpatches.Patch(color='darkgreen', label='Bottom 5 Parks')
ax.legend(handles=[top_bar, bottom_bar],framealpha=0)
#plt.savefig('Fatalities of Top and Bottom 5 park5',bbox_inches = 'tight', transparent=True)
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()

# %% [markdown]
# SHOW A GRAPH THAT COMPARES TOP AND BOTTOM 5 VISITORS TO FATALITIES

# %% [markdown]
# t=np.arange(0.01, 10.0, 0.01)
# top_and_bottom_5(t)
# Top_and_bottom_for_fatalities(2 * np.pi *t)
#
# fig, ax1=plt.subplots()
#
# color='tab:red'
# ax1.set_xlabel('park')
# ax1.set_ylabel('Visitors(1000s)', color=color)
# ax1.plot(t, top_and_bottom_5, color=color)
# ax1.tick_params(axis='y', labelcolor=color)
#
# ax2 = ax1.twinx()
#
# color = 'tab:blue'
# ax2.set_ylabel('Fatalities_per_million', color=color)
# ax2.plot(t, Top_and_bottom_for_fatalities, color=color)
# ax2.tick_params(axis='y', labelcolor=color)
#
# fig.tight_layout()
# plt.show()

# %% [markdown]
# fig, ax1 = plt.subplots()
#
# width= 0.35
# x = np.arange(len(top_and_bottom_5.park))
# ax1.bar(x - width/2, top_and_bottom_5, width, label='top_and_bottom_5')
#
# ax2 = ax1.twinx()
#
# ax2.bar(x + width/2, Top_and_bottom_for_fatalities, width, color='orange', label='Top_and_bottom_for_fatalities')
#
# ax1.set_xlabel('Park Name')
# ax1.set_ylabel('Visitors(1000s)')
# ax2.set_ylabel('Fatalities per million')
# plt.title('Clustered Bar Graph National Park Visitors to National Park Fatalities per capita')
#
# plt.xticks (x, park)
# fig.legend()
# plt.show()

# %%
Top_and_bottom_for_fatalities.head(10)
# Out:
#                                      Park Name  Fatalities_per_million  \
# 10           Guadalupe Mountains National Park                6.824105
# 2   Black Canyon Of The Gunnison National Park                5.947342
# 1                       Big Bend National Park                4.054993
# 5               Carlsbad Caverns National Park                3.519212
# 9    Great Sand Dunes National Park & Preserve                2.823142
# 6                        Glacier National Park                0.699785
# 8                    Grand Teton National Park                0.627547
# 13                Rocky Mountain National Park                0.550337
# 3                   Bryce Canyon National Park                0.495075
# 16                   Yellowstone National Park                0.474913
#
#         Color
# 10   darkblue
# 2    darkblue
# 1    darkblue
# 5    darkblue
# 9    darkblue
# 6   darkgreen
# 8   darkgreen
# 13  darkgreen
# 3   darkgreen
# 16  darkgreen

# %%
top_and_bottom_5_changed=top_and_bottom_5.rename(columns={'park':'Park Name'})

# %%
both_top_and_bottom=pd.merge(top_and_bottom_5_changed, Top_and_bottom_for_fatalities, left_on='Park Name', right_on='Park Name')
both_top_and_bottom
# Out:
#                                     Park Name  Visitors(1000s)      Rank  \
# 0                   Yellowstone National Park      3750.588235     Top 5
# 1                Rocky Mountain National Park      3693.529412     Top 5
# 2                   Grand Teton National Park      3007.529412     Top 5
# 3              Carlsbad Caverns National Park       403.647059  Bottom 5
# 4                      Big Bend National Park       403.588235  Bottom 5
# 5   Great Sand Dunes National Park & Preserve       376.352941  Bottom 5
# 6  Black Canyon Of The Gunnison National Park       249.882353  Bottom 5
# 7           Guadalupe Mountains National Park       183.764706  Bottom 5
#
#    Fatalities_per_million      Color
# 0                0.474913  darkgreen
# 1                0.550337  darkgreen
# 2                0.627547  darkgreen
# 3                3.519212   darkblue
# 4                4.054993   darkblue
# 5                2.823142   darkblue
# 6                5.947342   darkblue
# 7                6.824105   darkblue

# %%
colors=[]
for index, row in both_top_and_bottom.iterrows():
    if row['Rank']=='Top 5' and row['Fatalities_per_million']>2:
        colors.append('purple')

    elif row['Rank']== 'Bottom 5' and row['Fatalities_per_million']<=2:
        colors.append('orange')
    else:
        colors.append('darkgreen')
x=np.arange(len(both_top_and_bottom))
width=0.4
fig, ax1 = plt.subplots(figsize=(14,8))

ax1.bar(x-width/2,both_top_and_bottom['Visitors(1000s)'],width,label='Visitors(1000s)',color=colors)
ax2=ax1.twinx()
ax2.bar(x + width/2,both_top_and_bottom['Fatalities_per_million'],width,
label='Fatalities_per_million',
color='darkblue')

ax1.set_xlabel(' ')
ax1.set_ylabel('Visitors(1000s)',color='darkgreen', fontsize=14)
ax2.set_ylabel('Fatalities/million',color='darkblue',fontsize=14)
ax1.set_xticks(x)
ax1.set_xticklabels(both_top_and_bottom['Park Name'], rotation=90)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('Top and Bottom 5 Parks by Visitors and Fatalities with Color Coding', fontsize=16)
plt.tight_layout()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', borderaxespad=0,framealpha=0,fontsize=14)
ax2.legend(bbox_to_anchor=(1.05,1.1), loc='upper left', borderaxespad=0,framealpha=0,fontsize=14)
#plt.savefig('comparison6_plot.png',bbox_inches = 'tight', transparent=True)
plt.show()

# %%
both_top_and_bottom.corr(numeric_only=True)
# Out:
#                         Visitors(1000s)  Fatalities_per_million
# Visitors(1000s)                1.000000               -0.871694
# Fatalities_per_million        -0.871694                1.000000

# %%
deaths_population['Cause of Death']=deaths_population['Cause of Death'].str.title()
deaths_population
# Out:
#                                       Park Name  \
# 0    Black Canyon Of The Gunnison National Park
# 1                    Grand Canyon National Park
# 2                    Grand Canyon National Park
# 3                     Grand Teton National Park
# 4                     Grand Teton National Park
# ..                                          ...
# 687                  Bryce Canyon National Park
# 688                   Grand Teton National Park
# 689                  Bryce Canyon National Park
# 690                  Grand Canyon National Park
# 691                      Big Bend National Park
#
#                              Cause of Death         Intent       Outcome  \
# 0                                      Fall  Unintentional  Fatal Injury
# 1                                  Drowning  Unintentional  Fatal Injury
# 2                                      Fall  Unintentional  Fatal Injury
# 3                                      Fall  Unintentional  Fatal Injury
# 4                                      Fall  Unintentional  Fatal Injury
# ..                                      ...            ...           ...
# 687                             Flash Flood  Unintentional  Fatal Injury
# 688                            Undetermined  Unintentional  Fatal Injury
# 689                            Undetermined   Undetermined  Fatal Injury
# 690                            Undetermined   Undetermined  Fatal Injury
# 691  Medical - Not During Physical Activity        Medical  Fatal Injury
#
#         Sex     Age Range        Activity  month  Year  Visitors(1000s)
# 0    Female         15-24    Not Reported      2  2007            220.0
# 1      Male         55-64  Vessel Related      3  2007           4414.0
# 2      Male  Not Reported    Not Reported      4  2007           4414.0
# 3      Male         25-34        Climbing      4  2007           2589.0
# 4      Male         35-44        Climbing      4  2007           2589.0
# ..      ...           ...             ...    ...   ...              ...
# 687  Female           65+          Hiking      8  2023           2461.0
# 688    Male           65+    Not Reported      9  2023           3417.0
# 689    Male           65+    Not Reported      9  2023           2461.0
# 690    Male           65+          Hiking     11  2023           4734.0
# 691    Male         35-44           Other     12  2023            509.0
#
# [692 rows x 10 columns]

# %%
Cause_of_death_totals=deaths_population.groupby(['Cause of Death','Park Name', 'Year'])['Outcome'].count().to_frame().reset_index().rename(columns={'Outcome':'Fatality_Count'})
Cause_of_death_totals.head(10)
# Out:
#        Cause of Death                     Park Name  Year  Fatality_Count
# 0   Aircraft Incident     Grand Teton National Park  2018               2
# 1  Aircraft Incident      Canyonlands National Park  2008               2
# 2  Aircraft Incident      Grand Teton National Park  2012               1
# 3  Aircraft Incident      Grand Teton National Park  2013               2
# 4        Asphyxiation  Rocky Mountain National Park  2022               1
# 5           Avalanche         Glacier National Park  2008               1
# 6           Avalanche         Glacier National Park  2010               1
# 7           Avalanche         Glacier National Park  2011               1
# 8           Avalanche         Glacier National Park  2017               1
# 9           Avalanche     Grand Teton National Park  2011               2

# %%
(Cause_of_death_totals['Cause of Death'].unique())
# Out:
# array(['Aircraft Incident', 'Aircraft Incident ', 'Asphyxiation',
#        'Avalanche', 'Bicycle Only Crash', 'Drowning', 'Fall',
#        'Falling Tree/Branch', 'Firearm', 'Flash Flood', 'Homicide',
#        'Horseback Riding Incident', 'Hyperthermia', 'Hypothermia',
#        'Lightning Strike', 'Medical - During Physical Activity',
#        'Medical - Not During Physical Activity', 'Medical - Unknown',
#        'Motor Vehicle Crash', 'Poisoning - Alcohol',
#        'Poisoning - Carbon Monoxide', 'Poisoning - Drugs', 'Rockfall',
#        'Skiing Incident', 'Snowboard Incident', 'Suicide', 'Undetermined',
#        'Vessel Incident', 'Widlife Incident '], dtype=object)

# %% [markdown]
# ##### sns.scatterplot(data = Cause_of_death_totals,
#                x = 'Year',
#                y = 'Fatality_Count',
#                hue = 'Cause of Death',
#                palette = ['blue', 'coral', 'green']),
# plt.legend(bbox_to_anchor = (1,1), loc='upper left')

# %%
(Cause_of_death_totals['Cause of Death'].value_counts())
# Out:
# Cause of Death
# Fall                                      90
# Medical - During Physical Activity        52
# Undetermined                              52
# Suicide                                   41
# Drowning                                  36
# Medical - Not During Physical Activity    34
# Motor Vehicle Crash                       31
# Hyperthermia                              28
# Avalanche                                 10
# Hypothermia                               10
# Medical - Unknown                          8
# Lightning Strike                           4
# Flash Flood                                4
# Skiing Incident                            3
# Poisoning - Drugs                          3
# Widlife Incident                           3
# Aircraft Incident                          3
# Homicide                                   2
# Rockfall                                   2
# Vessel Incident                            2
# Horseback Riding Incident                  1
# Poisoning - Alcohol                        1
# Poisoning - Carbon Monoxide                1
# Firearm                                    1
# Falling Tree/Branch                        1
# Snowboard Incident                         1
# Bicycle Only Crash                         1
# Asphyxiation                               1
# Aircraft Incident                          1
# Name: count, dtype: int64

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Medical - Not During Physical Activity','Medical')
Cause_of_death_totals['Cause of Death']
# Out:
# 0       Aircraft Incident
# 1      Aircraft Incident
# 2      Aircraft Incident
# 3      Aircraft Incident
# 4            Asphyxiation
#               ...
# 422       Vessel Incident
# 423       Vessel Incident
# 424     Widlife Incident
# 425     Widlife Incident
# 426     Widlife Incident
# Name: Cause of Death, Length: 427, dtype: object

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Medical - During Physical Activity', 'Medical')

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Medical - Unknown','Medical')
Cause_of_death_totals['Cause of Death']
# Out:
# 0       Aircraft Incident
# 1      Aircraft Incident
# 2      Aircraft Incident
# 3      Aircraft Incident
# 4            Asphyxiation
#               ...
# 422       Vessel Incident
# 423       Vessel Incident
# 424     Widlife Incident
# 425     Widlife Incident
# 426     Widlife Incident
# Name: Cause of Death, Length: 427, dtype: object

# %%
(Cause_of_death_totals['Cause of Death'].value_counts())
# Out:
# Cause of Death
# Medical                        94
# Fall                           90
# Undetermined                   52
# Suicide                        41
# Drowning                       36
# Motor Vehicle Crash            31
# Hyperthermia                   28
# Hypothermia                    10
# Avalanche                      10
# Lightning Strike                4
# Flash Flood                     4
# Skiing Incident                 3
# Poisoning - Drugs               3
# Widlife Incident                3
# Aircraft Incident               3
# Homicide                        2
# Rockfall                        2
# Vessel Incident                 2
# Horseback Riding Incident       1
# Poisoning - Alcohol             1
# Poisoning - Carbon Monoxide     1
# Firearm                         1
# Falling Tree/Branch             1
# Snowboard Incident              1
# Bicycle Only Crash              1
# Asphyxiation                    1
# Aircraft Incident               1
# Name: count, dtype: int64

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Aircraft Incident ','Aircraft Incident')

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Poisoning - Carbon Monoxide','Poisoning')

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Poisoning - Alcohol','Poisoning')

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Poisoning - Drugs','Poisoning')

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Skiing Incident','Winter Sports')

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Snowboard Incident','Winter Sports')

# %%
Cause_of_death_totals['Cause of Death']=Cause_of_death_totals['Cause of Death'].str.replace('Asphyxiation','Medical')

# %%
Cause_of_death_totals['Cause of Death'].value_counts().reset_index()
# Out:
#                Cause of Death  count
# 0                     Medical     95
# 1                        Fall     90
# 2                Undetermined     52
# 3                     Suicide     41
# 4                    Drowning     36
# 5         Motor Vehicle Crash     31
# 6                Hyperthermia     28
# 7                 Hypothermia     10
# 8                   Avalanche     10
# 9                   Poisoning      5
# 10              Winter Sports      4
# 11           Lightning Strike      4
# 12          Aircraft Incident      4
# 13                Flash Flood      4
# 14          Widlife Incident       3
# 15                   Homicide      2
# 16                   Rockfall      2
# 17            Vessel Incident      2
# 18  Horseback Riding Incident      1
# 19                    Firearm      1
# 20        Falling Tree/Branch      1
# 21         Bicycle Only Crash      1

# %%
Cause_of_death_totals.groupby('Year').head()
# Out:
#         Cause of Death                          Park Name  Year  \
# 0    Aircraft Incident          Grand Teton National Park  2018
# 1    Aircraft Incident          Canyonlands National Park  2008
# 2    Aircraft Incident          Grand Teton National Park  2012
# 3    Aircraft Incident          Grand Teton National Park  2013
# 4              Medical       Rocky Mountain National Park  2022
# ..                 ...                                ...   ...
# 98                Fall          Grand Teton National Park  2011
# 107               Fall          Grand Teton National Park  2023
# 108               Fall  Guadalupe Mountains National Park  2023
# 119               Fall       Rocky Mountain National Park  2020
# 148           Homicide       Rocky Mountain National Park  2020
#
#      Fatality_Count
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 1
# ..              ...
# 98                1
# 107               2
# 108               1
# 119               2
# 148               1
#
# [85 rows x 4 columns]

# %%
Cause_of_death_totals_millions=pd.merge(Cause_of_death_totals, new_group, left_on='Park Name', right_on='Park Name')
Cause_of_death_totals_millions
# Out:
#         Cause of Death                     Park Name  Year  Fatality_Count  \
# 0    Aircraft Incident     Grand Teton National Park  2018               2
# 1    Aircraft Incident     Canyonlands National Park  2008               2
# 2    Aircraft Incident     Grand Teton National Park  2012               1
# 3    Aircraft Incident     Grand Teton National Park  2013               2
# 4              Medical  Rocky Mountain National Park  2022               1
# ..                 ...                           ...   ...             ...
# 422    Vessel Incident    Grand Canyon National Park  2021               1
# 423    Vessel Incident     Grand Teton National Park  2014               1
# 424  Widlife Incident      Grand Teton National Park  2018               1
# 425  Widlife Incident      Yellowstone National Park  2011               2
# 426  Widlife Incident      Yellowstone National Park  2015               1
#
#      Fatalities_per_million
# 0                  0.627547
# 1                  2.697197
# 2                  0.627547
# 3                  0.627547
# 4                  0.550337
# ..                      ...
# 422                0.788882
# 423                0.627547
# 424                0.627547
# 425                0.474913
# 426                0.474913
#
# [427 rows x 5 columns]

# %% [markdown]
# Cause_of_death_totals_millions=Cause_of_death_totals_millions.drop(columns='Fatality_Count')
# Cause_of_death_totals_millions

# %%
Cause_of_death_totals_millions['Cause of Death'].value_counts().plot(kind='barh', color='darkblue')
plt.title('Number of Deaths per Cause', fontsize=16)
plt.ylabel('Cause of Death', fontsize=14)
plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Number of deaths per cause5',bbox_inches = 'tight', transparent=True);
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %%
Deaths_grouped_million=Cause_of_death_totals_millions.groupby('Cause of Death')['Fatalities_per_million'].sum().reset_index()
Deaths_grouped_million
# Out:
#                Cause of Death  Fatalities_per_million
# 0           Aircraft Incident                4.579839
# 1                   Avalanche                6.487212
# 2          Bicycle Only Crash                2.408332
# 3                    Drowning               35.288937
# 4                        Fall              100.303869
# 5         Falling Tree/Branch                0.474913
# 6                     Firearm                0.474913
# 7                 Flash Flood                2.784729
# 8                    Homicide                1.025250
# 9   Horseback Riding Incident                0.627547
# 10               Hyperthermia               62.062695
# 11                Hypothermia               10.373655
# 12           Lightning Strike                2.623176
# 13                    Medical              125.355118
# 14        Motor Vehicle Crash               38.118622
# 15                  Poisoning                6.122227
# 16                   Rockfall                1.327332
# 17                    Suicide               58.175406
# 18               Undetermined               78.293376
# 19            Vessel Incident                1.416429
# 20          Widlife Incident                 1.577374
# 21              Winter Sports                2.432979

# %%
Total_fatalities=Deaths_grouped_million['Fatalities_per_million'].mean()
Total_fatalities
# Out:
# 24.651542384106026

# %%
Deaths_grouped_million['Primary_deaths']=np.where(Deaths_grouped_million.Fatalities_per_million>6.2,Deaths_grouped_million['Cause of Death'],'Other')
Deaths_grouped_million.head(30)
# Out:
#                Cause of Death  Fatalities_per_million       Primary_deaths
# 0           Aircraft Incident                4.579839                Other
# 1                   Avalanche                6.487212            Avalanche
# 2          Bicycle Only Crash                2.408332                Other
# 3                    Drowning               35.288937             Drowning
# 4                        Fall              100.303869                 Fall
# 5         Falling Tree/Branch                0.474913                Other
# 6                     Firearm                0.474913                Other
# 7                 Flash Flood                2.784729                Other
# 8                    Homicide                1.025250                Other
# 9   Horseback Riding Incident                0.627547                Other
# 10               Hyperthermia               62.062695         Hyperthermia
# 11                Hypothermia               10.373655          Hypothermia
# 12           Lightning Strike                2.623176                Other
# 13                    Medical              125.355118              Medical
# 14        Motor Vehicle Crash               38.118622  Motor Vehicle Crash
# 15                  Poisoning                6.122227                Other
# 16                   Rockfall                1.327332                Other
# 17                    Suicide               58.175406              Suicide
# 18               Undetermined               78.293376         Undetermined
# 19            Vessel Incident                1.416429                Other
# 20          Widlife Incident                 1.577374                Other
# 21              Winter Sports                2.432979                Other

# %%
Deaths_grouped_million['Primary_deaths'].unique()
# Out:
# array(['Other', 'Avalanche', 'Drowning', 'Fall', 'Hyperthermia',
#        'Hypothermia', 'Medical', 'Motor Vehicle Crash', 'Suicide',
#        'Undetermined'], dtype=object)

# %%
Deaths_grouped_million['Percent Fatalities']=(Deaths_grouped_million['Fatalities_per_million']/Total_fatalities)*100
Deaths_grouped_million.head(25)
# Out:
#                Cause of Death  Fatalities_per_million       Primary_deaths  \
# 0           Aircraft Incident                4.579839                Other
# 1                   Avalanche                6.487212            Avalanche
# 2          Bicycle Only Crash                2.408332                Other
# 3                    Drowning               35.288937             Drowning
# 4                        Fall              100.303869                 Fall
# 5         Falling Tree/Branch                0.474913                Other
# 6                     Firearm                0.474913                Other
# 7                 Flash Flood                2.784729                Other
# 8                    Homicide                1.025250                Other
# 9   Horseback Riding Incident                0.627547                Other
# 10               Hyperthermia               62.062695         Hyperthermia
# 11                Hypothermia               10.373655          Hypothermia
# 12           Lightning Strike                2.623176                Other
# 13                    Medical              125.355118              Medical
# 14        Motor Vehicle Crash               38.118622  Motor Vehicle Crash
# 15                  Poisoning                6.122227                Other
# 16                   Rockfall                1.327332                Other
# 17                    Suicide               58.175406              Suicide
# 18               Undetermined               78.293376         Undetermined
# 19            Vessel Incident                1.416429                Other
# 20          Widlife Incident                 1.577374                Other
# 21              Winter Sports                2.432979                Other
#
#     Percent Fatalities
# 0            18.578307
# 1            26.315644
# 2             9.769500
# 3           143.151033
# 4           406.886788
# 5             1.926505
# 6             1.926505
# 7            11.296370
# 8             4.158970
# 9             2.545671
# 10          251.759886
# 11           42.081158
# 12           10.641024
# 13          508.508215
# 14          154.629765
# 15           24.835066
# 16            5.384377
# 17          235.990937
# 18          317.600315
# 19            5.745805
# 20            6.398682
# 21            9.869479

# %%
Deaths_grouped_million.to_csv('Deaths_grouped_million.csv', index=False)

# %%
Deaths_grouped_million.describe()
# Out:
#        Fatalities_per_million  Percent Fatalities
# count               22.000000           22.000000
# mean                24.651542          100.000000
# std                 36.976448          149.996488
# min                  0.474913            1.926505
# 25%                  1.456666            5.909024
# 50%                  3.682284           14.937339
# 75%                 37.411201          151.760082
# max                125.355118          508.508215

# %%
sns.boxplot(Deaths_grouped_million['Fatalities_per_million'])
# Out:
# <Axes: ylabel='Fatalities_per_million'>

# %%
Cause_of_death_totals_million=pd.merge(Cause_of_death_totals_millions,Deaths_grouped_million[['Cause of Death','Primary_deaths']],on='Cause of Death')
Cause_of_death_totals_million.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Fatalities_per_million Primary_deaths
# 0                0.627547          Other

# %%
Cause_of_death_totals.groupby(['Cause of Death','Park Name']).head()
# Out:
#         Cause of Death                     Park Name  Year  Fatality_Count
# 0    Aircraft Incident     Grand Teton National Park  2018               2
# 1    Aircraft Incident     Canyonlands National Park  2008               2
# 2    Aircraft Incident     Grand Teton National Park  2012               1
# 3    Aircraft Incident     Grand Teton National Park  2013               2
# 4              Medical  Rocky Mountain National Park  2022               1
# ..                 ...                           ...   ...             ...
# 422    Vessel Incident    Grand Canyon National Park  2021               1
# 423    Vessel Incident     Grand Teton National Park  2014               1
# 424  Widlife Incident      Grand Teton National Park  2018               1
# 425  Widlife Incident      Yellowstone National Park  2011               2
# 426  Widlife Incident      Yellowstone National Park  2015               1
#
# [298 rows x 4 columns]

# %%
Cause_of_death_totals.groupby(['Cause of Death','Park Name']).head()
# Out:
#         Cause of Death                     Park Name  Year  Fatality_Count
# 0    Aircraft Incident     Grand Teton National Park  2018               2
# 1    Aircraft Incident     Canyonlands National Park  2008               2
# 2    Aircraft Incident     Grand Teton National Park  2012               1
# 3    Aircraft Incident     Grand Teton National Park  2013               2
# 4              Medical  Rocky Mountain National Park  2022               1
# ..                 ...                           ...   ...             ...
# 422    Vessel Incident    Grand Canyon National Park  2021               1
# 423    Vessel Incident     Grand Teton National Park  2014               1
# 424  Widlife Incident      Grand Teton National Park  2018               1
# 425  Widlife Incident      Yellowstone National Park  2011               2
# 426  Widlife Incident      Yellowstone National Park  2015               1
#
# [298 rows x 4 columns]

# %% [markdown]
# BBC_total=Cause_of_death_totals.loc[Cause_of_death_totals_millions['Park Name']=='Big Bend National Park']
# BBC_total.loc[BBC_total['Year']==2023]

# %% [markdown]
# GC_total=Cause_of_death_totals_millions.loc[Cause_of_death_totals_millions['Park Name']=='Grand Canyon National Park']
# GC_total.loc[GC_total['Year']==2020]

# %%
Death_totals_per_year=(Cause_of_death_totals['Year'].value_counts().reset_index())
Death_totals_per_year
# Out:
#     Year  count
# 0   2018     40
# 1   2022     38
# 2   2017     36
# 3   2019     36
# 4   2021     36
# 5   2015     32
# 6   2014     31
# 7   2016     28
# 8   2013     23
# 9   2023     23
# 10  2010     22
# 11  2020     19
# 12  2009     15
# 13  2011     13
# 14  2008     12
# 15  2012     12
# 16  2007     11

# %%
Cause_of_death_totals.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count
# 0  Aircraft Incident  Grand Teton National Park  2018               2

# %% [markdown]
# FATALITIES IN THE NP PER YEAR

# %%
sns.relplot(x='Year', y='count', data=Cause_of_death_totals['Year'].value_counts().reset_index(), kind='line', color='darkgreen', linewidth=1.5)
plt.title('National Park Fatalities per Year', fontsize=16, fontweight='bold')
plt.ylabel=('Fatalities')
#plt.savefig('fatalities per year5',bbox_inches = 'tight', transparent=True)
plt.show();

# %%
Cause_of_death_totals_millions.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Fatalities_per_million
# 0                0.627547

# %%
pivot_Deaths_per_age=Deaths_per_age.pivot_table(index='Age Range',columns='Sex',values='count',aggfunc='sum')
pivot_Deaths_per_age.plot(kind='bar',stacked=False,figsize=(10,6), color=['darkgreen','darkblue','black'])
plt.title('Fatalities in the National Parks Comparing Age and Gender')
plt.xlabel('Age Range')

ax.legend(framealpha=0)
ax.set_title('fancy, transparent legends')
#plt.savefig('totals_bar_plot5.png',bbox_inches = 'tight', transparent=True)
plt.show()

# %%
Cause_of_death_totals_million.value_counts('Cause of Death')
# Out:
# Cause of Death
# Medical                      95
# Fall                         90
# Undetermined                 52
# Suicide                      41
# Drowning                     36
# Motor Vehicle Crash          31
# Hyperthermia                 28
# Hypothermia                  10
# Avalanche                    10
# Poisoning                     5
# Lightning Strike              4
# Aircraft Incident             4
# Flash Flood                   4
# Winter Sports                 4
# Widlife Incident              3
# Homicide                      2
# Rockfall                      2
# Vessel Incident               2
# Horseback Riding Incident     1
# Firearm                       1
# Falling Tree/Branch           1
# Bicycle Only Crash            1
# Name: count, dtype: int64

# %%
Cause_of_death_totals_million.head()
# Out:
#       Cause of Death                     Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident     Grand Teton National Park  2018               2
# 1  Aircraft Incident     Canyonlands National Park  2008               2
# 2  Aircraft Incident     Grand Teton National Park  2012               1
# 3  Aircraft Incident     Grand Teton National Park  2013               2
# 4            Medical  Rocky Mountain National Park  2022               1
#
#    Fatalities_per_million Primary_deaths
# 0                0.627547          Other
# 1                2.697197          Other
# 2                0.627547          Other
# 3                0.627547          Other
# 4                0.550337        Medical

# %% [markdown]
# (Cause_of_death_totals_million['Cause of Death'].value_counts().reset_index())

# %%
pivot_Cause_of_death_totals_million=Cause_of_death_totals_million.pivot_table(index='Year', columns='Primary_deaths',values='Fatalities_per_million',aggfunc='mean',fill_value=0)
pivot_Cause_of_death_totals_million.plot(kind='bar',stacked=True, figsize=(12,8))
plt.title('Cause of Deaths per Year', fontsize=16)
plt.xlabel(' ')

plt.legend(title='Cause of Death', framealpha=0)
#plt.savefig('cause of death per year5',bbox_inches = 'tight', transparent=True)
plt.show()

# %% [markdown]
# NOTES:
# Tuesday am: start getting more statistics and graphs
#             organize questions according to how I want my presentation to flow
#         pm: get useable lat and long, vertical, and wifi data for top and bottom comparison
#             begin to develope point system

# %% [markdown]
# *****NEED TO GRAPH ABOVE FATALITY AND CAUSE ONLY, THEN FATALITY AND PARK ONLY, THEN FATALITY BY YEAR****

# %%
Cause_of_death_totals.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count
# 0  Aircraft Incident  Grand Teton National Park  2018               2

# %%
total_deaths_per_year=Cause_of_death_totals_million.groupby('Year')['Fatality_Count'].count().reset_index()

# %%
total_deaths_per_year.head(1)
# Out:
#    Year  Fatality_Count
# 0  2007              11

# %% [markdown]
# Falls_of_deaths_per_year=Cause_of_death_totals_million.loc[Cause_of_death_totals_million['Primary_deaths']=='Falls'].groupby('Year')['Fatality_Count'].count()

# %% [markdown]
# death_counts['percentage_falls']=(death_counts['falls_deaths']/death_counts['total_deaths'])*100

# %% [markdown]
# total_deaths_per_year=Cause_of_death_totals.groupby('Year')['Fatality_Count'].sum()
# Falls_of_deaths_per_year=Cause_of_death_totals.loc[Cause_of_death_totals['group']=='Falls'].groupby('Year')['Fatality_Count'].sum()
# death_counts=pd.DataFrame({'total deaths':'total_deaths_per_year','falls_deaths':Falls_of_deaths_per_year}).fillna(0)
# death_counts['percentage_falls']=(death_counts[alls_deaths']/death_counts['total_deaths'])*100

# %%
SAR_df=pd.read_csv('../data/SAR.csv')
SAR_df.head()
# Out:
#                                       Park  Incidents  Open Cases  \
# 0               Grand Canyon National Park      785.0         4.0
# 1                   Yosemite National Park      732.0         5.0
# 2  Sequoia and Kings Canyon National Parks      503.0         3.0
# 3                Yellowstone National Park      371.0         1.0
# 4             Rocky Mountain National Park      341.0        19.0
#
#    Closed-Incident Only  Closed: Found  Closed: Not found
# 0                   689             89                  0
# 1                   665             51                  1
# 2                   485             14                  1
# 3                   363              0                  0
# 4                    17             50                  3

# %%
SAR_df=SAR_df.rename(columns={'Park':'Park Name','Closed-Incident Only':'Closed/Incident Only'})

# %%
List=['Petrified Forest National Park','Big Bend National Park','Carlsbad Caverns National Park','Arches National Park','Guadalupe Mountains National Park','Mesa Verde National Park','Bryce Canyon National Park','White Sands National Park','Great Sand Dunes National Park & Preserve','Glacier National Park','Saguaro National Park','Canyonlands National Park','Rocky Mountain National Park','Yellowstone National Park','Zion National Park','Grand Teton National Park','Grand Canyon National Park','Black Canyon Of The Gunnison National Park',]
SAR=SAR_df.loc[SAR_df['Park Name'].isin(List)]
SAR.head(15)
# Out:
#                              Park Name  Incidents  Open Cases  \
# 0           Grand Canyon National Park      785.0         4.0
# 3            Yellowstone National Park      371.0         1.0
# 4         Rocky Mountain National Park      341.0        19.0
# 5                   Zion National Park      285.0         0.0
# 7            Grand Teton National Park      224.0        13.0
# 9                 Arches National Park      202.0         0.0
# 11               Glacier National Park      165.0         0.0
# 17           Canyonlands National Park      122.0         1.0
# 20              Big Bend National Park      110.0         0.0
# 21          Bryce Canyon National Park      110.0         0.0
# 40   Guadalupe Mountains National Park       40.0         0.0
# 42               Saguaro National Park       37.0         0.0
# 86            Mesa Verde National Park       11.0         0.0
# 104     Carlsbad Caverns National Park        6.0         1.0
# 148     Petrified Forest National Park        1.0         0.0
#
#      Closed/Incident Only  Closed: Found  Closed: Not found
# 0                     689             89                  0
# 3                     363              0                  0
# 4                      17             50                  3
# 5                     285              0                  0
# 7                      14             98                  1
# 9                      49            115                  6
# 11                    164              0                  0
# 17                    113              5                  0
# 20                     97              7                  2
# 21                    110              0                  0
# 40                     35              1                  4
# 42                     32              4                  1
# 86                     11              0                  0
# 104                     5              0                  0
# 148                     1              0                  0

# %% [markdown]
# SAR STATIISTICAL DATA FOR INCIDENCES IN 15 OF THE 18 IMR NATIONAL PARKS 2007-2023

# %%
SAR['Incidents'].describe()
# Out:
# count     15.000000
# mean     187.333333
# std      204.482157
# min        1.000000
# 25%       38.500000
# 50%      122.000000
# 75%      254.500000
# max      785.000000
# Name: Incidents, dtype: float64

# %% [markdown]
# NEED TO CATEGORIZE PARK INTO LOW, MEDIUM, AND HIGH INCIDENT LEVELS
# CAN I DO THIS BASED ON QUADRANTS

# %%
sns.boxplot(SAR)
plt.xticks(rotation=60);

# %%
SAR.head()
# Out:
#                       Park Name  Incidents  Open Cases  Closed/Incident Only  \
# 0    Grand Canyon National Park      785.0         4.0                   689
# 3     Yellowstone National Park      371.0         1.0                   363
# 4  Rocky Mountain National Park      341.0        19.0                    17
# 5            Zion National Park      285.0         0.0                   285
# 7     Grand Teton National Park      224.0        13.0                    14
#
#    Closed: Found  Closed: Not found
# 0             89                  0
# 3              0                  0
# 4             50                  3
# 5              0                  0
# 7             98                  1

# %%
SAR.plot(kind='bar', x='Park Name', stacked = False, width=1.2 )
plt.title('Search and Rescue Incidences:2007-2023')
plt.xlabel('Park Name')
#plt.ylabel('Average number of Incidences')
plt.legend(bbox_to_anchor=(1, 1.05), loc='upper left', borderaxespad=2, framealpha=0)
#plt.savefig('SAR incidences per park2',bbox_inches = 'tight', transparent=True)
plt.show()

# %% [markdown]
# The below markdown cells have species data which will be analyzed at a later date

# %% [markdown]
# arches_species=pd.read_csv('data/ArchesNP.Species.csv')
# arches_species.head(1)

# %% [markdown]
# arches_species=arches_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])

# %% [markdown]
# big_bend_species=pd.read_csv('data/BigBendNP.Species.csv')

# %% [markdown]
# big_bend_species=big_bend_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# big_bend_species.head(1)

# %% [markdown]
# bryce_canyon_species=pd.read_csv('data/BryceCanyonNP.Species.csv')

# %% [markdown]
# bryce_canyon_species=bryce_canyon_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# bryce_canyon_species.head(1)

# %% [markdown]
# canyonlands_species=pd.read_csv('data/CanyonlandsNP.Species.csv')

# %% [markdown]
# canyonlands_species=canyonlands_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# canyonlands_species.head(1)

# %% [markdown]
# carlsbad_caverns_species=pd.read_csv('data/CarlsbadCavernsNP.Species.csv')

# %% [markdown]
# carlsbad_caverns_species=carlsbad_caverns_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# carlsbad_caverns_species.head(1)

# %% [markdown]
# grand_teton_species=pd.read_csv('data/GrandTetonNP.Species.csv')

# %% [markdown]
# grand_teton_species=grand_teton_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# grand_teton_species.head(1)

# %% [markdown]
# guadalupe_species=pd.read_csv('data/GuadalupeNP.Species.csv')

# %% [markdown]
# guadalupe_species=guadalupe_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# guadalupe_species.head(1)

# %% [markdown]
# glacier_species=pd.read_csv('data/GlacierNP.Species.csv')

# %% [markdown]
# glacier_species=glacier_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# glacier_species.head(1)

# %% [markdown]
# zion_species=pd.read_csv('data/ZionNP.Species.csv')

# %% [markdown]
# zion_species=zion_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# zion_species.head(1)

# %% [markdown]
# great_sand_dunes_species=pd.read_csv('data/GreatSandDunesNP.Species.csv')

# %% [markdown]
# great_sand_dunes_species=great_sand_dunes_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# great_sand_dunes_species.head(1)

# %% [markdown]
# yellowstone_species=pd.read_csv('data/YellowstoneNP.Species.csv')

# %% [markdown]
# yellowstone_species=yellowstone_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# yellowstone_species.head(1)

# %% [markdown]
# white_sands_species=pd.read_csv('data/WhiteSandsNP.Species.csv')

# %% [markdown]
# white_sands_species=white_sands_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# white_sands_species.head(1)

# %% [markdown]
# mesa_verde_species=pd.read_csv('data/MesaVerdeNP.Species.csv', encoding='latin1')

# %% [markdown]
# mesa_verde_species=mesa_verde_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# mesa_verde_species.head(1)

# %% [markdown]
# rocky_mountain_species=pd.read_csv('data/RockyMountainNP.Species.csv', encoding='latin1')

# %% [markdown]
# rocky_mountain_species=rocky_mountain_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# rocky_mountain_species.head(1)

# %% [markdown]
# petrified_forest_species=pd.read_csv('data/PetrifiedForest.NP.Species.csv', encoding='latin1')

# %% [markdown]
# petrified_forest_species=petrified_forest_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# petrified_forest_species.head(1)

# %% [markdown]
# saguaro_species=pd.read_csv('data/SaguaroNP.Species.csv')

# %% [markdown]
# saguaro_species=saguaro_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# saguaro_species.head(1)

# %% [markdown]
# grand_canyon_species=pd.read_csv('data/GrandCanyonNP.Species.csv', encoding='latin1')

# %% [markdown]
# grand_canyon_species=grand_canyon_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# grand_canyon_species.head(1)

# %% [markdown]
# grand_canyon_species.info()

# %% [markdown]
# black_canyon_species=pd.read_csv('data/BlackCanyonNP.Species.csv',encoding='latin1')

# %% [markdown]
# black_canyon_species=black_canyon_species.drop(columns=['Park Code','Category Sort','Category','Order','Family','Taxon Code','TSN','Taxon Record Status','Scientific Name','Synonyms'])
# black_canyon_species.head(1)

# %% [markdown]
# black_canyon_species.info()

# %% [markdown]
# species=pd.concat([black_canyon_species,grand_canyon_species,saguaro_species,petrified_forest_species,rocky_mountain_species,mesa_verde_species])
# species.head(1)

# %% [markdown]
# species_data=pd.concat([species,white_sands_species,great_sand_dunes_species,yellowstone_species,guadalupe_species,glacier_species,zion_species,
#                         grand_teton_species,carlsbad_caverns_species, canyonlands_species,bryce_canyon_species,big_bend_species,arches_species])

# %% [markdown]
# species_data

# %% [markdown]
# species_data.groupby('Park Name')['Common Names'].value_counts()

# %% [markdown]
# species_data.groupby('Common Names')['Occurrence'].value_counts()

# %% [markdown]
# species_data['Occurrence'].unique()

# %% [markdown]
# species_data['Common Names'].unique()

# %% [markdown]
# COMPARING TOP AND BOTTOM PARKS IN DETAIL

# %%
Top_and_bottom_for_fatalities=Top_and_bottom_for_fatalities.sort_values('Fatalities_per_million',ascending=False)
Top_and_bottom_for_fatalities.head(10)
# Out:
#                                      Park Name  Fatalities_per_million  \
# 10           Guadalupe Mountains National Park                6.824105
# 2   Black Canyon Of The Gunnison National Park                5.947342
# 1                       Big Bend National Park                4.054993
# 5               Carlsbad Caverns National Park                3.519212
# 9    Great Sand Dunes National Park & Preserve                2.823142
# 6                        Glacier National Park                0.699785
# 8                    Grand Teton National Park                0.627547
# 13                Rocky Mountain National Park                0.550337
# 3                   Bryce Canyon National Park                0.495075
# 16                   Yellowstone National Park                0.474913
#
#         Color
# 10   darkblue
# 2    darkblue
# 1    darkblue
# 5    darkblue
# 9    darkblue
# 6   darkgreen
# 8   darkgreen
# 13  darkgreen
# 3   darkgreen
# 16  darkgreen

# %%
Visitors_Fatality_merge.head(1)
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
#
#         Outcome     Sex Age Range      Activity  month  Year  Visitors(1000s)  \
# 0  Fatal Injury  Female     15-24  Not Reported      2  2007            220.0
#
#    Fatality_Count  Visitors  Fatalities_per_million
# 0               1  220000.0                4.545455

# %%
Cause_of_death_totals_millions.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Fatalities_per_million
# 0                0.627547

# %%
pivot_Deaths_per_age.reset_index().head(10)
# Out:
# Sex    Age Range  Female   Male  Unknown-Sex
# 0           0-14     6.0    3.0          NaN
# 1          15-24    20.0   57.0          2.0
# 2          25-34    23.0   79.0          NaN
# 3          35-44    15.0   72.0          NaN
# 4          45-54    21.0   56.0          NaN
# 5          55-64    29.0   99.0          NaN
# 6            65+    22.0  126.0          3.0
# 7    Unknown-Age    12.0   31.0         20.0

# %%
merge1_df=pd.merge(Cause_of_death_totals, SAR, left_on='Park Name', right_on='Park Name', how='left')
merge1_df.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Incidents  Open Cases  Closed/Incident Only  Closed: Found  \
# 0      224.0        13.0                  14.0           98.0
#
#    Closed: Not found
# 0                1.0

# %%
Visitors_Fatality_merge.head(1)
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
#
#         Outcome     Sex Age Range      Activity  month  Year  Visitors(1000s)  \
# 0  Fatal Injury  Female     15-24  Not Reported      2  2007            220.0
#
#    Fatality_Count  Visitors  Fatalities_per_million
# 0               1  220000.0                4.545455

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Aircraft Incident ','Aircraft Incident')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Poisoning - Carbon Monoxide','Poisoning')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Poisoning - Alcohol','Poisoning')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Poisoning - Drugs','Poisoning')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Skiing Incident','Winter Sports')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Snowboard Incident','Winter Sports')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Asphyxiation','Medical')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Medical - Not During Physical Activity','Medical')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Medical - During Physical Activity','Medical')

# %%
Visitors_Fatality_merge['Cause of Death']=Visitors_Fatality_merge['Cause of Death'].str.replace('Medical - Unknown','Medical')

# %%
merge2_df=pd.merge(Visitors_Fatality_merge, merge1_df, left_on=['Park Name','Cause of Death','Year','Fatality_Count'],
                   right_on=['Park Name','Cause of Death','Year','Fatality_Count'], how='left')

# %%
merge2_df.head()
# Out:
#                                     Park Name Cause of Death         Intent  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Unintentional
# 1                  Grand Canyon National Park       Drowning  Unintentional
# 2                  Grand Canyon National Park           Fall  Unintentional
# 3                   Grand Teton National Park           Fall  Unintentional
# 4                   Grand Teton National Park           Fall  Unintentional
#
#         Outcome     Sex     Age Range        Activity  month  Year  \
# 0  Fatal Injury  Female         15-24    Not Reported      2  2007
# 1  Fatal Injury    Male         55-64  Vessel Related      3  2007
# 2  Fatal Injury    Male  Not Reported    Not Reported      4  2007
# 3  Fatal Injury    Male         25-34        Climbing      4  2007
# 4  Fatal Injury    Male         35-44        Climbing      4  2007
#
#    Visitors(1000s)  Fatality_Count   Visitors  Fatalities_per_million  \
# 0            220.0               1   220000.0                4.545455
# 1           4414.0               1  4414000.0                0.226552
# 2           4414.0               4  4414000.0                0.906208
# 3           2589.0               2  2589000.0                0.772499
# 4           2589.0               2  2589000.0                0.772499
#
#    Incidents  Open Cases  Closed/Incident Only  Closed: Found  \
# 0        NaN         NaN                   NaN            NaN
# 1      785.0         4.0                 689.0           89.0
# 2      785.0         4.0                 689.0           89.0
# 3      224.0        13.0                  14.0           98.0
# 4      224.0        13.0                  14.0           98.0
#
#    Closed: Not found
# 0                NaN
# 1                0.0
# 2                0.0
# 3                1.0
# 4                1.0

# %%
merge2_df['Cause of Death']=merge2_df['Cause of Death'].str.replace('Medical - Unknown','Medical')

# %%
merge2_df['Cause of Death'].unique()
# Out:
# array(['Fall', 'Drowning', 'Undetermined', 'Motor Vehicle Crash',
#        'Aircraft Incident', 'Bicycle Only Crash', 'Avalanche',
#        'Hyperthermia', 'Hypothermia', 'Poisoning', 'Widlife Incident ',
#        'Lightning Strike', 'Firearm', 'Medical', 'Suicide',
#        'Winter Sports', 'Falling Tree/Branch', 'Vessel Incident',
#        'Flash Flood', 'Horseback Riding Incident', 'Rockfall', 'Homicide'],
#       dtype=object)

# %%
merge2_df=merge2_df.drop(columns=['Outcome', 'Activity','Intent']).rename(columns={'Fatality_Count':'Fatality Count','Fatalities_per_million':
                                                                        'Fatalities per Million'})

# %%
List=['Grand Canyon National Park','Big Bend National Park','Carlsbad Caverns National Park','Black Canyon Of The Gunnison National Park','Canyonlands National Park',
'Guadalupe Mountains National Park','Mesa Verde National Park','Great Sand Dunes National Park & Preserve','Petrified Forest National Park','Bryce Canyon National Park']
merge2_df=merge2_df.loc[merge2_df['Park Name'].isin(List)]

merge2_df=merge2_df.drop(columns=['Open Cases','Closed/Incident Only','Closed: Found','Closed: Not found'])

# %%
List=['Yellowstone National Park','Big Bend National Park','Carlsbad Caverns National Park','Black Canyon Of The Gunnison National Park',
'Guadalupe Mountains National Park','Grand Teton National Park','Great Sand Dunes National Park & Preserve','Rocky Mountain National Park']
merge_finalSAR=merge2_df=merge2_df.loc[merge2_df['Park Name'].isin(List)]

# %%
merge2_df.head()
# Out:
#                                       Park Name       Cause of Death  \
# 0    Black Canyon Of The Gunnison National Park                 Fall
# 46                       Big Bend National Park         Hyperthermia
# 62    Great Sand Dunes National Park & Preserve          Hypothermia
# 75    Great Sand Dunes National Park & Preserve  Motor Vehicle Crash
# 112                      Big Bend National Park         Hyperthermia
#
#               Sex     Age Range  month  Year  Visitors(1000s)  Fatality Count  \
# 0          Female         15-24      2  2007            220.0               1
# 46   Not Reported  Not Reported      6  2009            364.0               1
# 62         Female         25-34     12  2009            290.0               1
# 75         Female           65+      6  2010            283.0               1
# 112          Male  Not Reported      6  2011            362.0               1
#
#      Visitors  Fatalities per Million  Incidents
# 0    220000.0                4.545455        NaN
# 46   364000.0                2.747253      110.0
# 62   290000.0                3.448276        NaN
# 75   283000.0                3.533569        NaN
# 112  362000.0                2.762431      110.0

# %%
merge2_df['Park Name'].unique()
# Out:
# array(['Black Canyon Of The Gunnison National Park',
#        'Big Bend National Park',
#        'Great Sand Dunes National Park & Preserve',
#        'Guadalupe Mountains National Park',
#        'Carlsbad Caverns National Park'], dtype=object)

# %%
grouped=merge2_df.groupby('Park Name')[['Visitors(1000s)', 'Incidents']].sum()
ax=grouped.plot(kind='bar',figsize=(10,6),width=0.8)

# %%
SAR.head(19)
# Out:
#                              Park Name  Incidents  Open Cases  \
# 0           Grand Canyon National Park      785.0         4.0
# 3            Yellowstone National Park      371.0         1.0
# 4         Rocky Mountain National Park      341.0        19.0
# 5                   Zion National Park      285.0         0.0
# 7            Grand Teton National Park      224.0        13.0
# 9                 Arches National Park      202.0         0.0
# 11               Glacier National Park      165.0         0.0
# 17           Canyonlands National Park      122.0         1.0
# 20              Big Bend National Park      110.0         0.0
# 21          Bryce Canyon National Park      110.0         0.0
# 40   Guadalupe Mountains National Park       40.0         0.0
# 42               Saguaro National Park       37.0         0.0
# 86            Mesa Verde National Park       11.0         0.0
# 104     Carlsbad Caverns National Park        6.0         1.0
# 148     Petrified Forest National Park        1.0         0.0
#
#      Closed/Incident Only  Closed: Found  Closed: Not found
# 0                     689             89                  0
# 3                     363              0                  0
# 4                      17             50                  3
# 5                     285              0                  0
# 7                      14             98                  1
# 9                      49            115                  6
# 11                    164              0                  0
# 17                    113              5                  0
# 20                     97              7                  2
# 21                    110              0                  0
# 40                     35              1                  4
# 42                     32              4                  1
# 86                     11              0                  0
# 104                     5              0                  0
# 148                     1              0                  0

# %%
new_SAR=pd.merge(Cause_of_death_totals_million,SAR, left_on='Park Name', right_on='Park Name')

# %%
new_SAR.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Fatalities_per_million Primary_deaths  Incidents  Open Cases  \
# 0                0.627547          Other      224.0        13.0
#
#    Closed/Incident Only  Closed: Found  Closed: Not found
# 0                    14             98                  1

# %%
merge1_df.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Incidents  Open Cases  Closed/Incident Only  Closed: Found  \
# 0      224.0        13.0                  14.0           98.0
#
#    Closed: Not found
# 0                1.0

# %%
url='https://en.wikipedia.org/wiki/List_of_national_parks_of_the_United_States_by_elevation'

# %%
import requests
from bs4 import BeautifulSoup as BS

# %%
response=requests.get(url)

# %%
soup=BS(response.text)

# %%
elevation_df=pd.read_html(str(soup.find('table')))[0]
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_31760\1803954606.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   elevation_df=pd.read_html(str(soup.find('table')))[0]

# %%
elevation_df=elevation_df.drop(columns=['Rank','Location','Mountain range','Location of lowest point']).rename(columns={'Park':'Park Name'})

# %%
elevation_df['Park Name'].unique()
# Out:
# array(['Denali', 'Wrangell-St. Elias', 'Glacier Bay', 'Sequoia',
#        'Mount Rainier', 'Rocky Mountain', 'Kings Canyon', 'Grand Teton',
#        'Hawaii Volcanoes', 'Great Sand Dunes', 'Yosemite', 'Great Basin',
#        'Yellowstone', 'Death Valley', 'Glacier', 'Lassen Volcanic',
#        'Lake Clark', 'Haleakala', 'North Cascades', 'Grand Canyon',
#        'Bryce Canyon', 'Black Canyon of the Gunnison', 'Capitol Reef',
#        'Crater Lake', 'Guadalupe Mountains', 'Zion', 'Saguaro',
#        'Mesa Verde', 'Gates of the Arctic', 'Olympic', 'Big Bend',
#        'Katmai', 'Canyonlands', 'Great Smoky Mountains',
#        'Carlsbad Caverns', 'Kenai Fjords', 'Petrified Forest',
#        'Joshua Tree', 'Arches', 'Wind Cave', 'Kobuk Valley',
#        'White Sands', 'Shenandoah', 'Badlands', 'Pinnacles',
#        'New River Gorge', 'American Samoa', 'Redwood',
#        'Theodore Roosevelt', 'Channel Islands', 'Acadia', 'Voyageurs',
#        'Hot Springs', 'Isle Royale', 'Virgin Islands', 'Cuyahoga Valley',
#        'Mammoth Cave', 'Indiana Dunes', 'Gateway Arch', 'Congaree',
#        'Everglades', 'Dry Tortugas', 'Biscayne'], dtype=object)

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Guadalupe Mountains','Guadalupe Mountains National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Mesa Verde','Mesa Verde National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Big Bend','Big Bend National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Canyonlands','Canyonlands National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Carlsbad Caverns','Carlsbad Caverns National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Petrified Forest','Petrified Forest National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Black Canyon of the Gunnison','Black Canyon Of The Gunnison National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Grand Canyon','Grand Canyon National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Great Sand Dunes','Great Sand Dunes National Park & Preserve')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Bryce Canyon','Bryce Canyon National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Yellowstone','Yellowstone National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Rocky Mountain','Rocky Mountain National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Zion','Zion National Park')

# %%
elevation_df['Park Name']=elevation_df['Park Name'].str.replace('Grand Teton','Grand Teton National Park')

# %%
New_List=['Grand Canyon National Park','Yellowstone National Park','Rocky Mountain National Park','Canyonlands National Park','Grand Teton National Park',
      'Carlsbad Caverns National Park','Big Bend National Park','Great Sand Dunes National Park & Preserve','Black Canyon Of The Gunnison National Park',
      'Guadalupe Mountains National Park']
elevation_df=elevation_df.loc[elevation_df['Park Name'].isin(New_List)]

# %%
elevation_df.head(10)
# Out:
#                                      Park Name  \
# 5                 Rocky Mountain National Park
# 7                    Grand Teton National Park
# 9    Great Sand Dunes National Park & Preserve
# 12                   Yellowstone National Park
# 19                  Grand Canyon National Park
# 21  Black Canyon Of The Gunnison National Park
# 24           Guadalupe Mountains National Park
# 30                      Big Bend National Park
# 32                   Canyonlands National Park
# 34              Carlsbad Caverns National Park
#
#                                             Peak name              Elevation  \
# 5                                          Longs Peak  14,259 feet (4,346 m)
# 7                                         Grand Teton  13,770 feet (4,200 m)
# 9                                     Tijeras Peak[4]  13,610 feet (4,150 m)
# 12                                         Eagle Peak  11,358 feet (3,462 m)
# 19  Lookout tower near the North Rim's main entran...   9,165 feet (2,793 m)
# 21                             Poison Spring Hill[12]   9,040 feet (2,760 m)
# 24                                     Guadalupe Peak   8,749 feet (2,667 m)
# 30                                         Emory Peak   7,825 feet (2,385 m)
# 32                                Cathedral Point[22]   7,120 feet (2,170 m)
# 34                                    Guadalupe Ridge   6,535 feet (1,992 m)
#
#            Minimum elevation       Vertical relief
# 5       7,630 feet (2,330 m)  6,629 feet (2,021 m)
# 7       6,310 feet (1,920 m)  7,460 feet (2,270 m)
# 9       7,520 feet (2,290 m)  6,090 feet (1,860 m)
# 12      5,282 feet (1,610 m)  6,076 feet (1,852 m)
# 19        1,173 feet (358 m)  7,992 feet (2,436 m)
# 21      5,440 feet (1,660 m)  3,600 feet (1,100 m)
# 24      3,636 feet (1,108 m)  5,113 feet (1,558 m)
# 30        1,715 feet (523 m)  6,110 feet (1,860 m)
# 32      3,730 feet (1,140 m)  3,390 feet (1,030 m)
# 34  3,596 feet (1,096 m)[25]    2,939 feet (896 m)

# %%
elevation_df.sort_values(by= 'Vertical relief', ascending=False).head(10)
# Out:
#                                      Park Name  \
# 19                  Grand Canyon National Park
# 7                    Grand Teton National Park
# 5                 Rocky Mountain National Park
# 30                      Big Bend National Park
# 9    Great Sand Dunes National Park & Preserve
# 12                   Yellowstone National Park
# 24           Guadalupe Mountains National Park
# 21  Black Canyon Of The Gunnison National Park
# 32                   Canyonlands National Park
# 34              Carlsbad Caverns National Park
#
#                                             Peak name              Elevation  \
# 19  Lookout tower near the North Rim's main entran...   9,165 feet (2,793 m)
# 7                                         Grand Teton  13,770 feet (4,200 m)
# 5                                          Longs Peak  14,259 feet (4,346 m)
# 30                                         Emory Peak   7,825 feet (2,385 m)
# 9                                     Tijeras Peak[4]  13,610 feet (4,150 m)
# 12                                         Eagle Peak  11,358 feet (3,462 m)
# 24                                     Guadalupe Peak   8,749 feet (2,667 m)
# 21                             Poison Spring Hill[12]   9,040 feet (2,760 m)
# 32                                Cathedral Point[22]   7,120 feet (2,170 m)
# 34                                    Guadalupe Ridge   6,535 feet (1,992 m)
#
#            Minimum elevation       Vertical relief
# 19        1,173 feet (358 m)  7,992 feet (2,436 m)
# 7       6,310 feet (1,920 m)  7,460 feet (2,270 m)
# 5       7,630 feet (2,330 m)  6,629 feet (2,021 m)
# 30        1,715 feet (523 m)  6,110 feet (1,860 m)
# 9       7,520 feet (2,290 m)  6,090 feet (1,860 m)
# 12      5,282 feet (1,610 m)  6,076 feet (1,852 m)
# 24      3,636 feet (1,108 m)  5,113 feet (1,558 m)
# 21      5,440 feet (1,660 m)  3,600 feet (1,100 m)
# 32      3,730 feet (1,140 m)  3,390 feet (1,030 m)
# 34  3,596 feet (1,096 m)[25]    2,939 feet (896 m)

# %% [raw]
# elevation_df=elevation_df.drop(columns=['Peak name','Minimum elevation'])

# %%
new_SAR['Park Name'].unique()
# Out:
# array(['Grand Teton National Park', 'Canyonlands National Park',
#        'Rocky Mountain National Park', 'Glacier National Park',
#        'Saguaro National Park', 'Big Bend National Park',
#        'Grand Canyon National Park', 'Yellowstone National Park',
#        'Zion National Park', 'Arches National Park',
#        'Guadalupe Mountains National Park', 'Bryce Canyon National Park',
#        'Carlsbad Caverns National Park', 'Mesa Verde National Park',
#        'Petrified Forest National Park'], dtype=object)

# %%
complete_df=pd.merge(Cause_of_death_totals_million, elevation_df, left_on='Park Name', right_on='Park Name')

# %%
complete_df2=pd.merge(merge2_df, elevation_df, left_on='Park Name', right_on='Park Name')

# %%
complete_df.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Fatalities_per_million Primary_deaths    Peak name              Elevation  \
# 0                0.627547          Other  Grand Teton  13,770 feet (4,200 m)
#
#       Minimum elevation       Vertical relief
# 0  6,310 feet (1,920 m)  7,460 feet (2,270 m)

# %%
complete_df2.head(1)
# Out:
#                                     Park Name Cause of Death     Sex  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Female
#
#   Age Range  month  Year  Visitors(1000s)  Fatality Count  Visitors  \
# 0     15-24      2  2007            220.0               1  220000.0
#
#    Fatalities per Million  Incidents               Peak name  \
# 0                4.545455        NaN  Poison Spring Hill[12]
#
#               Elevation     Minimum elevation       Vertical relief
# 0  9,040 feet (2,760 m)  5,440 feet (1,660 m)  3,600 feet (1,100 m)

# %%
complete_df2['Park Name'].unique()
# Out:
# array(['Black Canyon Of The Gunnison National Park',
#        'Big Bend National Park',
#        'Great Sand Dunes National Park & Preserve',
#        'Guadalupe Mountains National Park',
#        'Carlsbad Caverns National Park'], dtype=object)

# %%
complete_df['Park Name'].unique()
# Out:
# array(['Grand Teton National Park', 'Canyonlands National Park',
#        'Rocky Mountain National Park', 'Big Bend National Park',
#        'Grand Canyon National Park', 'Yellowstone National Park',
#        'Black Canyon Of The Gunnison National Park',
#        'Guadalupe Mountains National Park',
#        'Carlsbad Caverns National Park',
#        'Great Sand Dunes National Park & Preserve'], dtype=object)

# %%
complete_df.to_csv('Complete_df.csv', index=False)

# %%
Cause_of_death_totals.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count
# 0  Aircraft Incident  Grand Teton National Park  2018               2

# %%
Cause_of_death_totals['Park Name'].unique()
# Out:
# array(['Grand Teton National Park', 'Canyonlands National Park',
#        'Rocky Mountain National Park', 'Glacier National Park',
#        'Saguaro National Park', 'Big Bend National Park',
#        'Grand Canyon National Park', 'Yellowstone National Park',
#        'Zion National Park', 'Arches National Park',
#        'Black Canyon Of The Gunnison National Park',
#        'Guadalupe Mountains National Park', 'Bryce Canyon National Park',
#        'Carlsbad Caverns National Park', 'White Sands National Park',
#        'Great Sand Dunes National Park & Preserve',
#        'Mesa Verde National Park', 'Petrified Forest National Park'],
#       dtype=object)

# %% [markdown]
# full_df.head(1)

# %%
complete_df['Elevation']=complete_df['Elevation'].str[:-15]

# %%
complete_df.head()
# Out:
#       Cause of Death                     Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident     Grand Teton National Park  2018               2
# 1  Aircraft Incident     Canyonlands National Park  2008               2
# 2  Aircraft Incident     Grand Teton National Park  2012               1
# 3  Aircraft Incident     Grand Teton National Park  2013               2
# 4            Medical  Rocky Mountain National Park  2022               1
#
#    Fatalities_per_million Primary_deaths            Peak name Elevation  \
# 0                0.627547          Other          Grand Teton    13,770
# 1                2.697197          Other  Cathedral Point[22]     7,120
# 2                0.627547          Other          Grand Teton    13,770
# 3                0.627547          Other          Grand Teton    13,770
# 4                0.550337        Medical           Longs Peak    14,259
#
#       Minimum elevation       Vertical relief
# 0  6,310 feet (1,920 m)  7,460 feet (2,270 m)
# 1  3,730 feet (1,140 m)  3,390 feet (1,030 m)
# 2  6,310 feet (1,920 m)  7,460 feet (2,270 m)
# 3  6,310 feet (1,920 m)  7,460 feet (2,270 m)
# 4  7,630 feet (2,330 m)  6,629 feet (2,021 m)

# %% [markdown]
# I do not need to have visitor column in this df for needed information  fat/mill takes vis# into account

# %%
Big_Bend_df=complete_df.loc[complete_df['Park Name']=='Big Bend National Park']

# %%
Guadalupe_df=complete_df.loc[complete_df['Park Name']=='Guadalupe Mountains National Park']

# %%
Guadalupe_df
# Out:
#           Cause of Death                          Park Name  Year  \
# 80                  Fall  Guadalupe Mountains National Park  2023
# 155              Medical  Guadalupe Mountains National Park  2019
# 156              Medical  Guadalupe Mountains National Park  2022
# 181              Medical  Guadalupe Mountains National Park  2021
# 213  Motor Vehicle Crash  Guadalupe Mountains National Park  2015
# 292         Undetermined  Guadalupe Mountains National Park  2015
#
#      Fatality_Count  Fatalities_per_million       Primary_deaths  \
# 80                1                6.824105                 Fall
# 155               1                6.824105              Medical
# 156               1                6.824105              Medical
# 181               1                6.824105              Medical
# 213               2                6.824105  Motor Vehicle Crash
# 292               1                6.824105         Undetermined
#
#           Peak name Elevation     Minimum elevation       Vertical relief
# 80   Guadalupe Peak     8,749  3,636 feet (1,108 m)  5,113 feet (1,558 m)
# 155  Guadalupe Peak     8,749  3,636 feet (1,108 m)  5,113 feet (1,558 m)
# 156  Guadalupe Peak     8,749  3,636 feet (1,108 m)  5,113 feet (1,558 m)
# 181  Guadalupe Peak     8,749  3,636 feet (1,108 m)  5,113 feet (1,558 m)
# 213  Guadalupe Peak     8,749  3,636 feet (1,108 m)  5,113 feet (1,558 m)
# 292  Guadalupe Peak     8,749  3,636 feet (1,108 m)  5,113 feet (1,558 m)

# %%
Black_Canyon_df=complete_df.loc[complete_df['Park Name']=='Black Canyon Of The Gunnison National Park']

# %%
Big_Bend_df.groupby(['Cause of Death','Year'])['Fatality_Count'].count().reset_index()
# Out:
#          Cause of Death  Year  Fatality_Count
# 0              Drowning  2013               1
# 1              Drowning  2017               1
# 2                  Fall  2016               1
# 3                  Fall  2018               1
# 4                  Fall  2019               1
# 5          Hyperthermia  2009               1
# 6          Hyperthermia  2011               1
# 7          Hyperthermia  2013               1
# 8          Hyperthermia  2017               1
# 9          Hyperthermia  2019               1
# 10         Hyperthermia  2023               1
# 11              Medical  2014               1
# 12              Medical  2016               1
# 13              Medical  2017               1
# 14              Medical  2019               1
# 15              Medical  2022               2
# 16              Medical  2023               2
# 17  Motor Vehicle Crash  2023               1
# 18         Undetermined  2018               1
# 19         Undetermined  2019               1
# 20         Undetermined  2020               1
# 21         Undetermined  2022               1
# 22         Undetermined  2023               1

# %%
Guadalupe_df.groupby(['Year','Cause of Death'])['Fatality_Count'].count().reset_index()
# Out:
#    Year       Cause of Death  Fatality_Count
# 0  2015  Motor Vehicle Crash               1
# 1  2015         Undetermined               1
# 2  2019              Medical               1
# 3  2021              Medical               1
# 4  2022              Medical               1
# 5  2023                 Fall               1

# %%
Black_Canyon_df.groupby('Cause of Death')['Fatalities_per_million'].count().reset_index()
# Out:
#   Cause of Death  Fatalities_per_million
# 0           Fall                       2
# 1   Hyperthermia                       1
# 2        Suicide                       3
# 3   Undetermined                       1

# %% [markdown]
# Big_Bend_df.groupby('Cause of Death')['Fatalities_per_million'].count().reset_index()

# %%
import matplotlib.colors as mcolors

# %%
Guadalupe_df['Cause of Death'].value_counts().plot(kind='barh', color='darkgreen')
plt.title('Guadalupe NP',fontsize=16)

plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Guadalupe deaths per cause5',bbox_inches = 'tight', transparent=True)
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %%
Black_Canyon_df['Cause of Death'].value_counts().plot(kind='barh', color='darkgreen')
plt.title('Black Canyon NP',fontsize=16)

plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Black Canyon deaths per cause5',bbox_inches = 'tight', transparent=True)
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %%
Big_Bend_df['Cause of Death'].value_counts().plot(kind='barh', color='darkgreen')
plt.title('Big Bend NP',fontsize=16)

plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Big Bend deaths per cause5',bbox_inches = 'tight', transparent=True)
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %%
Grand_Canyon_National_Park_df=complete_df.loc[complete_df['Park Name']=='Grand Canyon National Park']

# %%
Rocky_Mountain_National_Park_df=complete_df.loc[complete_df['Park Name']=='Rocky Mountain National Park']

# %%
Yellowstone_National_Park_df=complete_df.loc[complete_df['Park Name']=='Yellowstone National Park']

# %%
Yellowstone_National_Park_df.groupby('Cause of Death')['Fatalities_per_million'].count().reset_index()
# Out:
#          Cause of Death  Fatalities_per_million
# 0              Drowning                       7
# 1                  Fall                       6
# 2   Falling Tree/Branch                       1
# 3               Firearm                       1
# 4              Homicide                       1
# 5           Hypothermia                       1
# 6               Medical                      16
# 7   Motor Vehicle Crash                       9
# 8             Poisoning                       1
# 9               Suicide                       6
# 10         Undetermined                       8
# 11    Widlife Incident                        2

# %%
Rocky_Mountain_National_Park_df.groupby('Cause of Death')['Fatality_Count'].count().reset_index()
# Out:
#       Cause of Death  Fatality_Count
# 0          Avalanche               1
# 1           Drowning               1
# 2               Fall              13
# 3           Homicide               1
# 4        Hypothermia               5
# 5   Lightning Strike               1
# 6            Medical              13
# 7          Poisoning               1
# 8            Suicide               8
# 9       Undetermined               7
# 10     Winter Sports               1

# %%
Yellowstone_National_Park_df['Cause of Death'].value_counts().plot(kind='barh', color='darkgreen')
plt.title('Yellowstone NP',fontsize=16)

plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Yellowstone deaths per cause5',bbox_inches = 'tight', transparent=True)
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %%
Grand_Canyon_National_Park_df['Cause of Death'].value_counts().plot(kind='barh', color='darkgreen')
plt.title('Grand Canyon NP',fontsize=16)

plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Grand Canyon deaths per cause5',bbox_inches = 'tight', transparent=True)
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %%
Rocky_Mountain_National_Park_df['Cause of Death'].value_counts().plot(kind='barh', color='darkgreen')
plt.title('Rocky Mountain NP',fontsize=16)

plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Rocky Mountain deaths per cause5',bbox_inches = 'tight', transparent=True)
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %%
Black_Canyon_Of_The_Gunnison_National_Park=complete_df.loc[complete_df['Park Name']=='Black Canyon Of The Gunnison National Park']
Black_Canyon_Of_The_Gunnison_National_Park.head()
# Out:
#     Cause of Death                                   Park Name  Year  \
# 41            Fall  Black Canyon Of The Gunnison National Park  2007
# 42            Fall  Black Canyon Of The Gunnison National Park  2013
# 112   Hyperthermia  Black Canyon Of The Gunnison National Park  2017
# 233        Suicide  Black Canyon Of The Gunnison National Park  2019
# 234        Suicide  Black Canyon Of The Gunnison National Park  2020
#
#      Fatality_Count  Fatalities_per_million Primary_deaths  \
# 41                1                5.947342           Fall
# 42                1                5.947342           Fall
# 112               1                5.947342   Hyperthermia
# 233               1                5.947342        Suicide
# 234               1                5.947342        Suicide
#
#                   Peak name Elevation     Minimum elevation  \
# 41   Poison Spring Hill[12]     9,040  5,440 feet (1,660 m)
# 42   Poison Spring Hill[12]     9,040  5,440 feet (1,660 m)
# 112  Poison Spring Hill[12]     9,040  5,440 feet (1,660 m)
# 233  Poison Spring Hill[12]     9,040  5,440 feet (1,660 m)
# 234  Poison Spring Hill[12]     9,040  5,440 feet (1,660 m)
#
#           Vertical relief
# 41   3,600 feet (1,100 m)
# 42   3,600 feet (1,100 m)
# 112  3,600 feet (1,100 m)
# 233  3,600 feet (1,100 m)
# 234  3,600 feet (1,100 m)

# %%
Black_Canyon_Of_The_Gunnison_National_Park.groupby('Cause of Death')['Fatality_Count'].count().reset_index()
# Out:
#   Cause of Death  Fatality_Count
# 0           Fall               2
# 1   Hyperthermia               1
# 2        Suicide               3
# 3   Undetermined               1

# %%
Visitors_Fatality_merge['Park Name'].unique()
# Out:
# array(['Black Canyon Of The Gunnison National Park',
#        'Grand Canyon National Park', 'Grand Teton National Park',
#        'Zion National Park', 'Yellowstone National Park',
#        'Rocky Mountain National Park', 'Canyonlands National Park',
#        'Saguaro National Park', 'Glacier National Park',
#        'Big Bend National Park',
#        'Great Sand Dunes National Park & Preserve',
#        'White Sands National Park', 'Bryce Canyon National Park',
#        'Mesa Verde National Park', 'Guadalupe Mountains National Park',
#        'Arches National Park', 'Carlsbad Caverns National Park',
#        'Petrified Forest National Park'], dtype=object)

# %% [markdown]
# grouped=Visitors_Fatality_merge.groupby(['Park Name','Cause of Death'])[Visitors_Fatality_merge['Fatality_Count']].()
# grouped=grouped.reset_index()
# top_cause_per_park=grouped.sort_values(by=['Park Name','Fatality_Count'],ascending=[True,False]).drop_duplicates(subset=['Park Name'])
# top_cause_per_park.head()

# %% [markdown]
# grouped.head()

# %%
complete_df2.head(1)
# Out:
#                                     Park Name Cause of Death     Sex  \
# 0  Black Canyon Of The Gunnison National Park           Fall  Female
#
#   Age Range  month  Year  Visitors(1000s)  Fatality Count  Visitors  \
# 0     15-24      2  2007            220.0               1  220000.0
#
#    Fatalities per Million  Incidents               Peak name  \
# 0                4.545455        NaN  Poison Spring Hill[12]
#
#               Elevation     Minimum elevation       Vertical relief
# 0  9,040 feet (2,760 m)  5,440 feet (1,660 m)  3,600 feet (1,100 m)

# %% [markdown]
# Unnecessary data to analyze

# %% [markdown]
# complete_df2['Fatalities per Million'] (complete_df2['Fatality Count'] / complete_df2['Visitors']) * 1e6
# grouped = complete_df.groupby(['Park Name', 'Cause of Death'])[['Fatalities per Million']].sum()
# grouped = grouped.reset_index()
# grouped.head()

# %% [markdown]
# top_cause_per_park = grouped.sort_values(by=['Park Name', 'Fatalities per Million'], ascending=[True, False])
# top_cause_per_park = top_cause_per_park.drop_duplicates(subset=['Park Name'])
# top_cause_per_park.head(10)

# %% [markdown]
# full_df.head()

# %% [markdown]
# top_cause_per_park2=pd.merge(top_cause_per_park, full_df, left_on=['Park Name', 'Fatalities per Million', 'Cause of Death'],  right_on=['Park Name', 'Fatalities per Million', 'Cause of Death'])
# top_cause_per_park2.drop(columns=['Minimum Elevation ft.','Minimum Elevation','Fatality Count','Visitors','group','Incidents'])
# top_cause_per_park2.head(10)

# %% [markdown]
# top_5_parks=full_df.groupby('Park Name')[['Fatality Count']].sum().sort_values(by='Fatality Count', ascending=False).head(5).index
# filtered_df=full_df[full_df['Park Name'].isin(top_5_parks)]
# cause_of_death_totals=filtered_df.groupby('Cause of Death')[['Fatality Count']].sum()
# top_5_causes=cause_of_death_totals.sort_values(by='Fatality Count',ascending=False).head(5)
# top_5_causes.head(5)

# %% [markdown]
# full_df.head(20)

# %% [markdown]
# fatality_counts_year=full_df.groupby('Year')['Fatality Count'].count().reset_index()
# fatality_counts_year

# %% [markdown]
# full_df[full_df['Fatality Count']==12]

# %% [markdown]
# full_df[full_df['Year']==2014]['Fatality Count'].value_counts()

# %%
complete_df2['Cause of Death'].value_counts().plot(kind='barh', color='darkblue')
plt.title('Number of Deaths per Cause', fontsize=16)

plt.xlabel('Number of Deaths', fontsize=14)
#plt.savefig('Number of deaths per cause2',bbox_inches = 'tight', transparent=True);
# Out:
# Text(0.5, 0, 'Number of Deaths')

# %% [markdown]
# Grand_Canyon_National_Park_df=full_df.loc[full_df['Park Name']=='Grand Canyon National Park']

# %% [markdown]
# Grand_Canyon_National_Park_df=full_df.loc[full_df['Park Name']=='Grand Canyon National Park']['Cause of Death'].value_counts()

# %% [markdown]
# Grand_Canyon_National_Park_df['Cause of Death'].value_counts()

# %% [markdown]
# Grand_Canyon_National_Park_df['Cause of Death'].value_counts().plot(kind='barh', color='darkblue')
# plt.title('Grand Canyon National Park', fontsize=16)
# plt.ylabel('Cause of Death', fontsize=14)
# plt.xlabel('Number of Deaths', fontsize=14)
# plt.savefig('deaths per cause3',bbox_inches = 'tight', transparent=True)

# %%
complete_df['Park Name'].unique()
# Out:
# array(['Grand Teton National Park', 'Canyonlands National Park',
#        'Rocky Mountain National Park', 'Big Bend National Park',
#        'Grand Canyon National Park', 'Yellowstone National Park',
#        'Black Canyon Of The Gunnison National Park',
#        'Guadalupe Mountains National Park',
#        'Carlsbad Caverns National Park',
#        'Great Sand Dunes National Park & Preserve'], dtype=object)

# %%
Year_2014_data=complete_df.loc[complete_df['Year']==2014]
Year_2014_data['Primary_deaths'].value_counts()
# Out:
# Primary_deaths
# Medical                8
# Fall                   4
# Other                  4
# Drowning               3
# Suicide                3
# Motor Vehicle Crash    2
# Hypothermia            1
# Undetermined           1
# Name: count, dtype: int64

# %%
SAR.head(10)
# Out:
#                        Park Name  Incidents  Open Cases  Closed/Incident Only  \
# 0     Grand Canyon National Park      785.0         4.0                   689
# 3      Yellowstone National Park      371.0         1.0                   363
# 4   Rocky Mountain National Park      341.0        19.0                    17
# 5             Zion National Park      285.0         0.0                   285
# 7      Grand Teton National Park      224.0        13.0                    14
# 9           Arches National Park      202.0         0.0                    49
# 11         Glacier National Park      165.0         0.0                   164
# 17     Canyonlands National Park      122.0         1.0                   113
# 20        Big Bend National Park      110.0         0.0                    97
# 21    Bryce Canyon National Park      110.0         0.0                   110
#
#     Closed: Found  Closed: Not found
# 0              89                  0
# 3               0                  0
# 4              50                  3
# 5               0                  0
# 7              98                  1
# 9             115                  6
# 11              0                  0
# 17              5                  0
# 20              7                  2
# 21              0                  0

# %%
plt.figure(figsize=(8, 5)) 
plt.plot(SAR['Park Name'], SAR['Incidents'], marker='o', linestyle='-', color='g', label='Value')
plt.xticks(rotation=90)
plt.grid()
plt.savefig('incidences per park',bbox_inches = 'tight', transparent=True)
plt.show()

# %% [markdown]
# SAR.plot.scatter(x='Park Name', y='Incidents', c='Open Cases', cmap='viridis')
# plt.xticks(rotation=90);

# %%
plt.bar(SAR['Park Name'], SAR['Incidents'], color='darkblue')
plt.xlabel('Park Name', fontsize=14)

plt.title('SAR Incidents per park', fontsize=16)
plt.xticks(rotation=90)
#plt.savefig('incidences per park',bbox_inches = 'tight', transparent=True)
plt.show()

# %% [markdown]
# Incidents_data.head().reset_index(drop=True)

# %%
group=complete_df.groupby(['Park Name', 'Primary_deaths'])['Fatalities_per_million'].sum().reset_index()
cause_count=group.groupby('Park Name')['Primary_deaths'].nunique()
cause_of_deaths_ppark=group.groupby('Park Name')['Primary_deaths'].apply(list)
cause_of_deaths_ppark.head()
# Out:
# Park Name
# Big Bend National Park                        [Drowning, Fall, Hyperthermia, Medical, Motor ...
# Black Canyon Of The Gunnison National Park          [Fall, Hyperthermia, Suicide, Undetermined]
# Canyonlands National Park                     [Drowning, Fall, Hyperthermia, Medical, Other,...
# Carlsbad Caverns National Park                                            [Hyperthermia, Other]
# Grand Canyon National Park                    [Drowning, Fall, Hyperthermia, Medical, Motor ...
# Name: Primary_deaths, dtype: object

# %%
group=complete_df.groupby(['Park Name', 'Primary_deaths','Year'])['Fatalities_per_million'].sum().reset_index()
Big_Bend=group.loc[group['Park Name']=='Big Bend National Park'].sort_values(by='Fatalities_per_million', ascending=False)
Big_Bend.head(10)
# Out:
#                  Park Name       Primary_deaths  Year  Fatalities_per_million
# 16  Big Bend National Park              Medical  2023                8.109985
# 15  Big Bend National Park              Medical  2022                8.109985
# 0   Big Bend National Park             Drowning  2013                4.054993
# 12  Big Bend National Park              Medical  2016                4.054993
# 21  Big Bend National Park         Undetermined  2022                4.054993
# 20  Big Bend National Park         Undetermined  2020                4.054993
# 19  Big Bend National Park         Undetermined  2019                4.054993
# 18  Big Bend National Park         Undetermined  2018                4.054993
# 17  Big Bend National Park  Motor Vehicle Crash  2023                4.054993
# 14  Big Bend National Park              Medical  2019                4.054993

# %%
Carlsbad_Caverns=group.loc[group['Park Name']=='Carlsbad Caverns National Park'].sort_values(by= 'Fatalities_per_million', ascending=False)
Carlsbad_Caverns.head()
# Out:
#                          Park Name Primary_deaths  Year  \
# 51  Carlsbad Caverns National Park   Hyperthermia  2017
# 52  Carlsbad Caverns National Park          Other  2021
#
#     Fatalities_per_million
# 51                3.519212
# 52                3.519212

# %%
##Averages for fatalities per year; Avg fatalities per park per year,

# %% [markdown]
# graph changes in  number of deaths per park over the years
# graph changes in causes of death over the years
# these are in slide 4, due to lack of documentation for some of the smaller parks, the numbers can be off

# %%
complete_df.head(1)
# Out:
#       Cause of Death                  Park Name  Year  Fatality_Count  \
# 0  Aircraft Incident  Grand Teton National Park  2018               2
#
#    Fatalities_per_million Primary_deaths    Peak name Elevation  \
# 0                0.627547          Other  Grand Teton    13,770
#
#       Minimum elevation       Vertical relief
# 0  6,310 feet (1,920 m)  7,460 feet (2,270 m)

# %%
complete_df['Park Name'].unique()
# Out:
# array(['Grand Teton National Park', 'Canyonlands National Park',
#        'Rocky Mountain National Park', 'Big Bend National Park',
#        'Grand Canyon National Park', 'Yellowstone National Park',
#        'Black Canyon Of The Gunnison National Park',
#        'Guadalupe Mountains National Park',
#        'Carlsbad Caverns National Park',
#        'Great Sand Dunes National Park & Preserve'], dtype=object)

# %%
List=['Big Bend National Park', 'Guadalupe Mountains National Park','Black Canyon Of The Gunnison National Park','Great Sand Dunes National Park & Preserve','Carlsbad Caverns National Park','Canyonlands National Park']
top5_complete_df=complete_df.loc[complete_df['Park Name'].isin(List)]

# %% [markdown]
# Data for elevations, and Vertical relief in fatalities top 2 and bottom 2 fall parks

# %%
top5_complete_df['Park Name'].unique()
# Out:
# array(['Canyonlands National Park', 'Big Bend National Park',
#        'Black Canyon Of The Gunnison National Park',
#        'Guadalupe Mountains National Park',
#        'Carlsbad Caverns National Park',
#        'Great Sand Dunes National Park & Preserve'], dtype=object)

# %%
top5_complete_df.head(10)
# Out:
#        Cause of Death                                   Park Name  Year  \
# 1   Aircraft Incident                   Canyonlands National Park  2008
# 11           Drowning                      Big Bend National Park  2013
# 12           Drowning                      Big Bend National Park  2017
# 13           Drowning                   Canyonlands National Park  2019
# 14           Drowning                   Canyonlands National Park  2022
# 38               Fall                      Big Bend National Park  2016
# 39               Fall                      Big Bend National Park  2018
# 40               Fall                      Big Bend National Park  2019
# 41               Fall  Black Canyon Of The Gunnison National Park  2007
# 42               Fall  Black Canyon Of The Gunnison National Park  2013
#
#     Fatality_Count  Fatalities_per_million Primary_deaths  \
# 1                2                2.697197          Other
# 11               1                4.054993       Drowning
# 12               1                4.054993       Drowning
# 13               1                2.697197       Drowning
# 14               1                2.697197       Drowning
# 38               1                4.054993           Fall
# 39               1                4.054993           Fall
# 40               1                4.054993           Fall
# 41               1                5.947342           Fall
# 42               1                5.947342           Fall
#
#                  Peak name Elevation     Minimum elevation  \
# 1      Cathedral Point[22]     7,120  3,730 feet (1,140 m)
# 11              Emory Peak     7,825    1,715 feet (523 m)
# 12              Emory Peak     7,825    1,715 feet (523 m)
# 13     Cathedral Point[22]     7,120  3,730 feet (1,140 m)
# 14     Cathedral Point[22]     7,120  3,730 feet (1,140 m)
# 38              Emory Peak     7,825    1,715 feet (523 m)
# 39              Emory Peak     7,825    1,715 feet (523 m)
# 40              Emory Peak     7,825    1,715 feet (523 m)
# 41  Poison Spring Hill[12]     9,040  5,440 feet (1,660 m)
# 42  Poison Spring Hill[12]     9,040  5,440 feet (1,660 m)
#
#          Vertical relief
# 1   3,390 feet (1,030 m)
# 11  6,110 feet (1,860 m)
# 12  6,110 feet (1,860 m)
# 13  3,390 feet (1,030 m)
# 14  3,390 feet (1,030 m)
# 38  6,110 feet (1,860 m)
# 39  6,110 feet (1,860 m)
# 40  6,110 feet (1,860 m)
# 41  3,600 feet (1,100 m)
# 42  3,600 feet (1,100 m)
